# %% [markdown]
# <img src="qiskit-heading.png" alt="Note: In order for images to show up in this jupyter notebook you need to select File => Trusted Notebook" align="middle">

# %% [markdown]
# # *Getting started with Qiskit Chemistry*
#
# Notebook prepared for QuID 2019 school Sep 10th 2019
#
# ***
# ### Contributors
# Lukas Moeller<sup>[1]</sup>, Igor Sokolov<sup>[1]</sup>, Pauline Ollitrault<sup>[1]</sup>, Panagiotis Barkoutsos<sup>[1]</sup>, Richard Chen<sup>[2]</sup>, Antonio Mezzacapo<sup>[2]</sup>, Marco Pistoia<sup>[2]</sup>, Stephen Wood<sup>[2]</sup>, Shaohan Hu<sup>[2]</sup>, Peng Liu<sup>[2]</sup>, Jay Gambetta<sup>[2]</sup>
# ### Affiliation
# - <sup>[1]</sup>IBM Research Zuerich
# - <sup>[2]</sup>IBMQ

# %% [markdown]
# ### Installation
#
# You have to have Qiskit installed to run it. See https://qiskit.org/documentation/install.html for installation guidelines.
#
# For a last minite installation (without Anaconda):
#
# - install Python 3.7 by downloading from official website
#
# and then, in the Terminal, write
# - pip install qiskit
#
# this will install qiskit-aqua that contains the chemistry package and all dependencies.

# %% [markdown]
# ### Introduction
# This notebook introduces you to Qiskit Chemistry. It demonstrates the computation of the ground state of molecular Hydrogen using the Variational Quantum Eigensolver (VQE). Different variational forms and qubit
# mappings can be used.
#
# ### Variational algorithm for quantum chemistry problems
#
# In order to find the optimal parameters $\boldsymbol\theta^*$ that correspond to the ground state wavefunction, we set up a closed optimization loop between quantum and classical computer, based on some stochastic or gradient-based optimization routine.
#
# 1. Map the fermionic Hamiltonian $H$ to a qubit Hamiltonian $H_P$.
# 2. Choose the maximum depth and type of the quantum circuit (Variational Form) to efficiently explore the Hilbert space.
# 3. Choose a set of controls $\boldsymbol\theta$ and make a trial function $|\psi(\boldsymbol\theta)\rangle$.
# 4. Evaluate the energy $E(\boldsymbol\theta) = \langle\psi(\boldsymbol\theta)~|H_P|~\psi(\boldsymbol\theta)\rangle$ by sampling each Pauli term individually, or sets of Pauli terms (grouped commuting Paulis) that can be measured in the same tensor product basis.
# 5. Use a classical optimizer (SPSA, L-BFGS-B, COBYLA ...) to choose a new set of controls $\boldsymbol\theta$.
# 6. Run the classical optimization until the energy has converged, hopefully close to the real solution $\boldsymbol\theta^*$, global minimum, and return the last value of $E(\boldsymbol\theta)$.
#
#
# References and additional details:
#
# [1] A. Kandala, A. Mezzacapo, K. Temme, M. Takita, M. Brink, J. M. Chow, and J. M. Gambetta, *Hardware-efficient Variational Quantum Eigensolver for Small Molecules and Quantum Magnets*, Nature 549, 242 (2017), and references therein.
#
# [2] Panagiotis Kl. Barkoutsos, Jerome F. Gonthier, Igor Sokolov, Nikolaj Moll, Gian Salis, Andreas Fuhrer, Marc Ganzhorn, Daniel J. Egger, Matthias Troyer, Antonio Mezzacapo, Stefan Filipp, and Ivano Tavernelli *Quantum algorithms for electronic structure calculations: Particle-hole Hamiltonian and optimized wave-function expansions* Phys. Rev. A 98, 022322 – Published 20 August 2018

# %% [markdown]
# ### Starting with H2
#
# In this notebook, we decompose the computation of the ground state energy of a molecule into 4 steps:
#   1. Define a molecule and get integrals `h1, h2` from a computational chemistry driver (PySCF in this case)
#   2. Construct a Fermionic Hamiltonian and map it onto a qubit Hamiltonian using a fermion-to-qubit `mapping`.
#   3. Instantiate and initialize dynamically-loaded algorithmic components, such as the quantum algorithm `vqe`, the `optimizer` and `variational form` it will use, and the `initial_state` to initialize the variational form.
#   4. Run the algorithm on a quantum `backend` and retrieve the results.

# %% [markdown]
# First, we have to import the necessary components to run our simulation. We will explain the different components at the point, where they are used.

# %%
# import common packages

import numpy as np
import matplotlib.pyplot as plt

from qiskit import Aer, IBMQ, QuantumRegister
from qiskit.providers.ibmq import least_busy
from qiskit.providers.aer import noise

# lib from Qiskit Aqua

from qiskit.aqua import Operator, QuantumInstance
from qiskit.aqua.algorithms import VQE, ExactEigensolver
from qiskit.aqua.components.optimizers import COBYLA, SPSA, L_BFGS_B
from qiskit.aqua.components.variational_forms import RY, RYRZ, SwapRZ


# lib from Qiskit Aqua Chemistry

from qiskit.chemistry import QiskitChemistry
from qiskit.chemistry import FermionicOperator
from qiskit.chemistry.drivers import PySCFDriver, UnitsType
from qiskit.chemistry.aqua_extensions.components.variational_forms import UCCSD
from qiskit.chemistry.aqua_extensions.components.initial_states import HartreeFock

# setup qiskit.chemistry logging

import logging
from qiskit.chemistry import set_qiskit_chemistry_logging

# function that allows us to create multiple figures in single notebook cell
def show_figure(fig):
    dummy_fig = plt.figure()
    new_dummy_fig_manager = dummy_fig.canvas.manager
    new_dummy_fig_manager.canvas.figure = fig
    fig.set_canvas(new_dummy_fig_manager.canvas)

# %% [markdown]
# Set the logger specific level of prints so you can get all information on what is actually happening for understanding every step of code's execution.
#
# - set `logging.DEBUG` for maximum amount of information on the execution and `logging.ERROR` for only displaying errors.
# - `logging.INFO` allows to monitor the execution without getting too much information.

# %%
set_qiskit_chemistry_logging(logging.INFO) # choose among DEBUG, INFO, WARNING, ERROR, CRITICAL and NOTSET

# %% [markdown]
# ### Step 1: define a molecule and compute the integrals
# Here, we use H2 in sto3g basis with `PySCFDriver` as an example.
# The `molecule` object records the information from the PySCF driver. You can also use other drivers such as Gaussian,

# %%
driver = PySCFDriver(atom='H .0 .0 .0; H .0 .0 1.6', unit=UnitsType.ANGSTROM,
                     charge=0, spin=0, basis='sto3g')
molecule = driver.run()
# Out:
# 2019-09-09 23:09:17,126:qiskit.chemistry.drivers.pyscfd.integrals:INFO: PySCF kernel() converged: True, e(hf): -0.8817324499460555
# 2019-09-09 23:09:17,129:qiskit.chemistry.drivers.pyscfd.integrals:INFO: HF Electronic dipole moment: [-0.        -0.        -3.0235618]
# 2019-09-09 23:09:17,130:qiskit.chemistry.drivers.pyscfd.integrals:INFO: Nuclear dipole moment: [0.        0.        3.0235618]
# 2019-09-09 23:09:17,131:qiskit.chemistry.drivers.pyscfd.integrals:INFO: Total dipole moment: [0. 0. 0.]

# %% [markdown]
# Extract the data from the molecule object

# %%
nuclear_repulsion_energy = molecule.nuclear_repulsion_energy
num_particles = molecule.num_alpha + molecule.num_beta
num_spin_orbitals = molecule.num_orbitals * 2

print("HF energy: {}".format(molecule.hf_energy - molecule.nuclear_repulsion_energy))
print("# of electrons: {}".format(num_particles))
print("# of spin orbitals: {}".format(num_spin_orbitals))
# Out:
# HF energy: -1.2124682067710555
# # of electrons: 2
# # of spin orbitals: 4

# %% [markdown]
# If you want to know all the contents of the given class to know more do

# %%
print("Contents of molecule object: \n{}".format(sorted(molecule.__dir__())))
# Out:
# Contents of molecule object:
# ['BOHR', 'DEBYE', 'QMOLECULE_VERSION', 'Z', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_filename', 'atom_symbol', 'atom_xyz', 'core_orbitals', 'eri', 'filename', 'has_dipole_integrals', 'hcore', 'hcore_B', 'hf_energy', 'kinetic', 'load', 'log', 'mo_coeff', 'mo_coeff_B', 'mo_eri_ints', 'mo_eri_ints_BA', 'mo_eri_ints_BB', 'mo_onee_ints', 'mo_onee_ints_B', 'molecular_charge', 'multiplicity', 'nuclear_dipole_moment', 'nuclear_repulsion_energy', 'num_alpha', 'num_atoms', 'num_beta', 'num_orbitals', 'one_body_integrals', 'onee_to_spin', 'oneeints2mo', 'orbital_energies', 'orbital_energies_B', 'origin_driver_config', 'origin_driver_name', 'origin_driver_version', 'overlap', 'remove_file', 'reverse_dipole_sign', 'save', 'symbols', 'two_body_integrals', 'twoe_to_spin', 'twoeints2mo', 'twoeints2mo_general', 'x_dip_ints', 'x_dip_mo_ints', 'x_dip_mo_ints_B', 'x_dipole_integrals', 'y_dip_ints', 'y_dip_mo_ints', 'y_dip_mo_ints_B', 'y_dipole_integrals', 'z_dip_ints', 'z_dip_mo_ints', 'z_dip_mo_ints_B', 'z_dipole_integrals']

# %% [markdown]
# You can also use the `shift+tab` command when clicking on a class/method to produce its docstring in Jupyter Notebook.

# %% [markdown]
# ### Step 2: Prepare qubit Hamiltonian

# %% [markdown]
# #### Fermionic Hamiltonians
#
# The Hamiltonians describing systems of interacting fermions can be expressed in second quantization language, considering fermionic creation (annihilation) operators $a^\dagger_\alpha(a_\alpha)$, relative to the $\alpha$-th fermionic mode. In the case of molecules, the $\alpha$ labels stand for the different atomic or molecular orbitals.
#
# Within the second-quantization framework, a generic molecular Hamiltonian with $M$ orbitals can be written as
# $$H =H_1+H_2=\sum_{\alpha, \beta=0}^{M-1} h_{1,\alpha \beta} \, a^\dagger_{\alpha} a_{\beta} +\frac{1}{2}  \sum_{\alpha, \beta, \gamma, \delta = 0}^{M-1} h_{2,\alpha \beta \gamma \delta}\, a^\dagger_{\alpha} a^\dagger_{\gamma} a_{\delta} a_{\beta},$$
# with the one-body terms representing the kinetic energy of the electrons and the potential energy that they experience in the presence of the nuclei,
# $$ h_{1,\alpha\beta}=\int d\boldsymbol x_1\Psi_\alpha(\boldsymbol{x}_1) \left(-\frac{\boldsymbol\nabla_1^2}{2}+\sum_{i} \frac{Z_i}{|\boldsymbol{r}_{1i}|}\right)\Psi_\beta (\boldsymbol{x}_1),$$
# and their interactions via Coulomb forces
# $$ h_{2,\alpha\beta\gamma\delta}=\int\int d \boldsymbol{x}_1 d \boldsymbol{x}_2 \Psi_\alpha^*(\boldsymbol{x}_1)\Psi_\beta(\boldsymbol{x}_1)\frac{1}{|\boldsymbol{r}_{12}|}\Psi_\gamma^*(\boldsymbol{x}_2)\Psi_\delta(\boldsymbol{x}_2),$$
# where we have defined the nuclei charges $Z_i$, the nuclei-electron and electron-electron separations $\boldsymbol{r}_{1i}$ and $\boldsymbol{r}_{12}$, the $\alpha$-th orbital wavefunction $\Psi_\alpha(\boldsymbol{x}_1)$, and we have assumed that the spin is conserved in the spin-orbital indices $\alpha,\beta$ and $\alpha,\beta,\gamma,\delta$.
#
# [1] A. Kandala, A. Mezzacapo, K. Temme, M. Takita, M. Brink, J. M. Chow, and J. M. Gambetta, *Hardware-efficient Variational Quantum Eigensolver for Small Molecules and Quantum Magnets*, Nature 549, 242 (2017)
#
# Now we can create a `FermionicOperator` that represents the electronic Hamiltonian

# %%
# get the integrals from molecule object
h1 = molecule.one_body_integrals
h2 = molecule.two_body_integrals

# create a fermionic operator
ferOp = FermionicOperator(h1=h1, h2=h2)

# %% [markdown]
# Here, we define the `map_type` for mapping the fermionic Hamitonian to the qubit Hamiltonian to transform the creation and anihilation operators into Pauli strings.
# For the particular `'parity'` mapping, we can further reduce the number of qubits needed, later on.

# %%
map_type = 'parity' # 'jordan_wigner', 'parity', 'bravyi_kitaev', 'bksf'

# %% [markdown]
# For more information about fermion-to-qubit mappings such as parity refer for example to:
#
# [3] Jacob T. Seeley, Martin J. Richard, and Peter J. Love *The Bravyi-Kitaev transformation for quantum computation of electronic structure*
# J. Chem. Phys. 137, 224109 (2012); https://doi.org/10.1063/1.4768229

# %% [markdown]
# We get a list of Pauli strings, which represent our Hamiltonian in the quantum computer.

# %%
# if 'parity' mapping is selected, reduce the number of qubits (-2 qubits)
qubit_reduction = True if map_type == 'parity' else False

qubitOp = ferOp.mapping(map_type=map_type, threshold=10**-10) # paulis with coefs below threshold are not considered
qubitOp = qubitOp.two_qubit_reduced_operator(num_particles) if qubit_reduction else qubitOp
qubitOp.chop(10**-10) # cut out the pauli strings with prefacator smaller then

print(qubitOp)
qubitOp.paulis

# to see all the contents of given class
# qubitOp.__dir__()
# one can group the Paulis
# qubitOp.to_grouped_paulis()
# qubitOp.paulis
# Out:
# Representation: paulis, qubits: 2, size: 5
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/base_operator.py:182: DeprecationWarning: two_qubit_reduced_operator method is deprecated and it will be removed after 0.6. Now it is moved to the `Z2Symmetries` class as a classmethod. Z2Symmeteries.two_qubit_reduction(num_particles)
#   DeprecationWarning)
# [[(-0.9932985015661868+0j), Pauli(z=[False, False], x=[False, False])],
#  [(0.11130874730832119+0j), Pauli(z=[True, False], x=[False, False])],
#  [(-0.11130874730832119+0j), Pauli(z=[False, True], x=[False, False])],
#  [(-0.0034477894117742047+0j), Pauli(z=[True, True], x=[False, False])],
#  [(0.23590128539850805+0j), Pauli(z=[False, False], x=[True, True])]]

# %% [markdown]
# where the x,y,z are the usual Pauli matrices:
#
# $X= \begin{pmatrix} 0&1 \\ 1&0 \end{pmatrix}$,
# $Y= \begin{pmatrix} 0&-i \\ i&0 \end{pmatrix}$,
# $Z= \begin{pmatrix} 1&0 \\ 0&-1 \end{pmatrix}$
#
# and the notation
# `Pauli(z=[False, False], x=[True, True])`
# represents the Pauli string $(Z^{0}X^{1})\otimes (Z^{0}X^{1}) = X \otimes X = XX$
#
# using the property $Z^1X^1 = iY$.
# We can also print the Paulis in a more convinient form:

# %%
for pauli in qubitOp.paulis:
    print(pauli[0],str(pauli[1]))
# Out:
# (-0.9932985015661868+0j) II
# (0.11130874730832119+0j) IZ
# (-0.11130874730832119+0j) ZI
# (-0.0034477894117742047+0j) ZZ
# (0.23590128539850805+0j) XX

# %% [markdown]
# ### Step 3: Initiate and configure dynamically-loaded instances
#
# #### Scheme of Variational Quantum Eigensolver (VQE) Algorithm
# <img title="Schematic of VQE" src="vqe.jpg" alt="Drawing" style="width: 700px;"/>
#
# [3] Nikolaj Moll et al 2018 Quantum Sci. Technol. 3 030503
#
# To run VQE we require
# - VQE algorithm
# - Classical Optimizer
# - Prepare the initial state into Hartree-Fock state
# - Variational form
# - Backend (where to run our algorithm)

# %% [markdown]
# Here we setup the classical optimizer. We can choose between different optimizers in Qiskit. Each optimizer can have different meanings of iterations $\neq$ number of energy evaluations (calculate gradients for all dimensions then perform a step). So it is advised to look at each optimizer and understand the parameters.

# %%
max_iter = 200 # maximum number of iterations

# optimizer = COBYLA(maxiter=max_iter)
# optimizer = SPSA(maxiter=max_iter)
optimizer = L_BFGS_B(maxiter=max_iter)

# %% [markdown]
# Now we have to setup an initial state for our optimization to start with. We can use the `HartreeFock` state.

# %%
HF_state = HartreeFock(qubitOp.num_qubits, num_spin_orbitals, num_particles, map_type, 
                       qubit_reduction)
HF_state_vec = HF_state.construct_circuit(mode='vector')

# we can use qiskit's vizualisation module to plot the state
from qiskit.visualization import plot_state_city
plot_state_city(HF_state_vec)
# Out:
# 2019-09-09 22:23:11,059:qiskit.chemistry.aqua_extensions.components.initial_states.hartree_fock:INFO: We assume that the number of alphas and betas are the same.

# %%
# you might want to visualise on the Bloch sphere for a non-superposition state
from qiskit.visualization import plot_state_city, plot_bloch_multivector
plot_bloch_multivector(HF_state_vec)

# %% [markdown]
# ### Variational Forms
# #### Hardware efficient heuristic Ansatz
# Note that, as opposed to the classical case, in the case of a quantum chemistry Hamiltonian one has to sample over non-computational states that are superpositions, and therefore take advantage of using a quantum computer in the sampling part of the algorithm. Motivated by the quantum nature of the answer, we define a variational trial ansatz in this way:
#
# $$|\psi(\boldsymbol\theta)\rangle  = [U_\mathrm{single}(\boldsymbol\theta) U_\mathrm{entangler}]^m |+\rangle$$
#
# where $U_\mathrm{entangler}$ is a collection of cPhase gates (fully entangling gates), $U_\mathrm{single}(\boldsymbol\theta) = \prod_{i=1}^n Y(\theta_{i})Z(\theta_{n+i})$ are single-qubit $Y$ and $Z$ rotation, $n$ is the number of qubits and $m$ is the depth of the quantum circuit.
#
# References and additional details:
#
# [1] A. Kandala, A. Mezzacapo, K. Temme, M. Takita, M. Brink, J. M. Chow, and J. M. Gambetta, *Hardware-efficient Variational Quantum Eigensolver for Small Molecules and Quantum Magnets*, Nature 549, 242 (2017)
#
# #### Unitary Coupled Cluster (UCC) Ansatz
#
# Another approach is to take inspiration from the classical UCC and electronic Hamiltonian and parameterise each excitation (single $\hat{T}_{1}(\vec{\theta})=\sum_{i ; m} \theta_{i}^{m} \hat{a}_{m}^{\dagger} \hat{a}_{i}$ and double $\hat{T}_{2}(\vec{\theta})=\frac{1}{2} \sum_{i, j ; m, n} \theta_{i, j}^{m, n} \hat{a}_{n}^{\dagger} \hat{a}_{m}^{\dagger} \hat{a}_{j} \hat{a}_{i}$) in operator $\hat T(\vec{\theta}) = \hat{T}_{1}(\vec{\theta}) + \hat{T}_{2}(\vec{\theta}) $ with an angle $\theta$. The unitary coupled cluster (UCC) wavefunction is given by:
# $$|\psi(\boldsymbol\theta)\rangle= e^{\hat{T}(\theta)-\hat{T}^{\dagger}(\theta)}\left|\Phi_{0}\right\rangle$$
# where the cluster operator is
# $$ U(\boldsymbol\theta)=e^{\hat{T}(\theta)-\hat{T}^{\dagger}(\theta)} $$
# the
# where $\left|\Phi_{0}\right\rangle$ is the HF state (e.g. $\left|1100\right\rangle$ for H2 in STO-3G basis)

# %%
var_form_uccsd = UCCSD(qubitOp.num_qubits, depth=1, 
                   num_orbitals=num_spin_orbitals, num_particles=num_particles, 
                   active_occupied=None, active_unoccupied=None, # you could modify the active space here 
                   initial_state=HF_state, qubit_mapping=map_type,
                   two_qubit_reduction=qubit_reduction, num_time_slices=1)

var_form_swaprz = SwapRZ(qubitOp.num_qubits, depth=1, 
                   initial_state=HF_state)

var_form_ryrz = RYRZ(qubitOp.num_qubits, depth=1, 
                   initial_state=HF_state)

# var_form_ry = RY(qubitOp.num_qubits, depth=1, 
#                    initial_state=HF_state)
# Out:
# 2019-09-09 22:23:13,866:qiskit.chemistry.aqua_extensions.components.variational_forms.uccsd:INFO: We assume that the number of alphas and betas are the same.

# %% [markdown]
# ### [Optional] Setup token to run the experiment on a real device
# If you would like to run the experiment on a real device, you need to setup your account first.
#
# Note: If you do not store your token yet, use `IBMQ.save_account('MY_API_TOKEN')` to store it first.
# ### Choose a simulator or real device
# You can use the `qasm_simulator` or `ibmq_qasm_simulator` (cloud qasm simulator) to simulate faithfully the operations a real quantum computer would do. If you just want to simulate the processing of a quantum computer for now, you have to use `Aer`, which provides you with the `statevector_simulator`.

# %%
simultation_type = 'state_vector'# qasm, qasm_cloud, real_device, state_vector

# %%
if simultation_type == 'qasm':
    
    sv_mode = False
    qasm_simulator = Aer.get_backend('qasm_simulator') # qasm_simulator, ibmq_qasm_simulator

    # uncomment this and put your token from the IBMQ website.
    #IBMQ.save_account('Your IBMQ API-token', overwrite=True)
    
    IBMQ.load_accounts() # connect with your token to IBMQ
    provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
    print(provider.backends()) # lists available backends
    
    # set the noise model
    device = provider.get_backend('ibmq_16_melbourne') # ibmq_16_melbourne 
    properties = device.properties()
    coupling_map = device.configuration().coupling_map
    noise_model = noise.device.basic_device_noise_model(properties)
    basis_gates = noise_model.basis_gates
    shots = 8192 # choose the maximal number of shots (8192 is max on the ibmq_qasm_simulator)
    num_qubits = qubitOp.num_qubits
    
    # run on qasm_simulator 
    quantum_instance = QuantumInstance(qasm_simulator, shots=shots, basis_gates=basis_gates, coupling_map=coupling_map, noise_model=noise_model)

    # all the details of noise model
    print(noise_model.to_dict())
    
elif simultation_type == 'qasm_cloud':
    
    sv_mode = False
    # uncomment this and put your token from the IBMQ website.
    #IBMQ.save_account('Your IBMQ API-token', overwrite=True)
    IBMQ.load_accounts() # connect with your token to IBMQ
    provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
    print(provider.backends()) # lists available backends
    
    qasm_simulator_cloud = provider.get_backend('ibmq_qasm_simulator') # ibmq_16_melbourne , ibmq_qasm_simulator
    # set the qasm cloud simulator 
    quantum_instance = QuantumInstance(qasm_simulator_cloud, shots=shots)

    # all the details of noise model
    print(noise_model.to_dict())

elif simultation_type == 'real_device':
    
    sv_mode = False
    # uncomment this and put your token from the IBMQ website.
    #IBMQ.save_account('Your IBMQ API-token', overwrite=True)
    
    IBMQ.load_accounts() # connect with your token to IBMQ
    provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
    print(provider.backends()) # lists available backends
    
    # set the noise model
    device = provider.get_backend('ibmq_16_melbourne') # ibmq_16_melbourne 
    
    # run on qasm_simulator 
    quantum_instance = QuantumInstance(device, shots=shots)

    # all the details of noise model
    print(noise_model.to_dict())
    
elif simultation_type == 'state_vector':
    
    sv_simulator = Aer.get_backend('statevector_simulator')
    quantum_instance = QuantumInstance(sv_simulator) 
    sv_mode = True
    num_qubits = qubitOp.num_qubits
else:
    raise Exception('Please select for simultation_type == qasm, qasm_cloud, real_device, state_vector')
# Out:
# 2019-09-09 17:59:53,305:qiskit.aqua.quantum_instance:INFO: statevector backend only works with shot=1, change shots from 1024 to 1.
# 2019-09-09 17:59:53,306:qiskit.aqua.quantum_instance:INFO:
# Qiskit Terra version: 0.9.0
# Backend: 'statevector_simulator (AerProvider)', with following setting:
# {'basis_gates': ['u1', 'u2', 'u3', 'cx', 'cz', 'cu1', 'id', 'x', 'y', 'z', 'h', 's', 'sdg', 't', 'tdg', 'ccx', 'swap', 'multiplexer', 'snapshot', 'unitary', 'reset', 'initialize'], 'coupling_map': None}
# {'pass_manager': None, 'initial_layout': None, 'seed_transpiler': None, 'optimization_level': None}
# RunConfig(max_credits=10, shots=1)
# {'timeout': None}
# {}
# {}
# Measurement mitigation: None

# %% [markdown]
# If you want more details on the noise models and , refer to tutorial:
#
# https://github.com/Qiskit/qiskit-iqx-tutorials/blob/master/qiskit/advanced/aer/2_device_noise_simulation.ipynb

# %% [markdown]
# We prepared everything to setup the Variational Quantum Eigensolver at this point. We initialize 3 different VQE objects to show the circuits (`uccsd, ryrz, swaprz`) each one will use to evalute the energy.

# %%
vqe_uccsd = VQE(qubitOp, var_form_uccsd, optimizer)
vqe_ryrz = VQE(qubitOp, var_form_ryrz, optimizer)
vqe_swaprz = VQE(qubitOp, var_form_swaprz, optimizer)
# Out:
# 2019-09-09 17:59:54,791:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO:
# ==================== Setting of VQE ============================
# Algorithm: VQE
# -- quantum_instance: None
# -- var_form: <qiskit.chemistry.aqua_extensions.components.variational_forms.uccsd.UCCSD object at 0x134dc5c50>
# -- optimizer: <qiskit.aqua.components.optimizers.l_bfgs_b.L_BFGS_B object at 0x1345a7400>
# -- cost_fn: <bound method VQE._energy_evaluation of <qiskit.aqua.algorithms.adaptive.vqe.vqe.VQE object at 0x13886c080>>
# -- initial_point: [0. 0. 0.]
# -- callback: None
# -- operator: Representation: paulis, qubits: 2, size: 5
# -- eval_count: 0
# -- aux_operators: []
# -- auto_conversion: True
# ===============================================================
# Variational Form: UCCSD
# -- num_parameters: 3
# -- num_qubits: 2
# -- bounds: [(-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793)]
# -- z2_symmetries: Z2 symmetries:
# Symmetries:
# Single-Qubit Pauli X:
# Cliffords:
# Qubit index:
# []
# Tapering values:
# []
# -- depth: 1
# -- num_orbitals: 4
# -- num_alpha: 1
# -- num_beta: 1
# -- num_particles: [1, 1]
# -- initial_state: <qiskit.chemistry.aqua_extensions.components.initial_states.hartree_fock.HartreeFock object at 0x13475f518>
# -- qubit_mapping: parity
# -- two_qubit_reduction: True
# -- num_time_slices: 1
# -- shallow_circuit_concat: True
# -- single_excitations: [[0, 1], [2, 3]]
# -- double_excitations: [[0, 1, 2, 3]]
# -- hopping_ops: [<qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x134cd53c8>, <qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x134cd6240>, <qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x13475f3c8>]
# -- logging_construct_circuit: True
# ===============================================================
# Optimizer: L_BFGS_B
# -- gradient_support_level: 2
# -- bounds_support_level: 2
# -- initial_point_support_level: 3
# -- options: {'maxfun': 1000, 'maxiter': 200, 'factr': 10, 'iprint': -1, 'epsilon': 1e-08}
# -- max_evals_grouped: 1
# ===============================================================
#
# 2019-09-09 17:59:54,792:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO:
# ==================== Setting of VQE ============================
# Algorithm: VQE
# -- quantum_instance: None
# -- var_form: <qiskit.aqua.components.variational_forms.ryrz.RYRZ object at 0x134820cf8>
# -- optimizer: <qiskit.aqua.components.optimizers.l_bfgs_b.L_BFGS_B object at 0x1345a7400>
# -- cost_fn: <bound method VQE._energy_evaluation of <qiskit.aqua.algorithms.adaptive.vqe.vqe.VQE object at 0x13886c0b8>>
# -- initial_point: Random seed
# -- callback: None
# -- operator: Representation: paulis, qubits: 2, size: 5
# -- eval_count: 0
# -- aux_operators: []
# -- auto_conversion: True
# ===============================================================
# Variational Form: RYRZ
# -- num_parameters: 8
# -- num_qubits: 2
# -- bounds: [(-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793)]
# -- depth: 1
# -- entangler_map: [[0, 1]]
# -- entangled_qubits: [0, 1]
# -- initial_state: <qiskit.chemistry.aqua_extensions.components.initial_states.hartree_fock.HartreeFock object at 0x13475f518>
# -- entanglement_gate: cz
# -- skip_unentangled_qubits: False
# ===============================================================
# Optimizer: L_BFGS_B
# -- gradient_support_level: 2
# -- bounds_support_level: 2
# -- initial_point_support_level: 3
# -- options: {'maxfun': 1000, 'maxiter': 200, 'factr': 10, 'iprint': -1, 'epsilon': 1e-08}
# -- max_evals_grouped: 1
# ===============================================================
#
# 2019-09-09 17:59:54,794:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO:
# ==================== Setting of VQE ============================
# Algorithm: VQE
# -- quantum_instance: None
# -- var_form: <qiskit.aqua.components.variational_forms.swaprz.SwapRZ object at 0x13495f240>
# -- optimizer: <qiskit.aqua.components.optimizers.l_bfgs_b.L_BFGS_B object at 0x1345a7400>
# -- cost_fn: <bound method VQE._energy_evaluation of <qiskit.aqua.algorithms.adaptive.vqe.vqe.VQE object at 0x13873a4a8>>
# -- initial_point: Random seed
# -- callback: None
# -- operator: Representation: paulis, qubits: 2, size: 5
# -- eval_count: 0
# -- aux_operators: []
# -- auto_conversion: True
# ===============================================================
# Variational Form: SWAPRZ
# -- num_parameters: 5
# -- num_qubits: 2
# -- bounds: [(-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793)]
# -- depth: 1
# -- entangler_map: [[0, 1]]
# -- entangled_qubits: [0, 1]
# -- initial_state: <qiskit.chemistry.aqua_extensions.components.initial_states.hartree_fock.HartreeFock object at 0x13475f518>
# -- skip_unentangled_qubits: False
# ===============================================================
# Optimizer: L_BFGS_B
# -- gradient_support_level: 2
# -- bounds_support_level: 2
# -- initial_point_support_level: 3
# -- options: {'maxfun': 1000, 'maxiter': 200, 'factr': 10, 'iprint': -1, 'epsilon': 1e-08}
# -- max_evals_grouped: 1
# ===============================================================

# %% [markdown]
# To get a better understanding, what is happening on the quantum computer, we can have a look on the circuit that is executed. For each Pauli, we have a circuit that is used to evaluate its expectation value.

# %%
for pauli in qubitOp.paulis:
    print('Circuit for:', pauli[1])

circuit_uccsd = vqe_uccsd.construct_circuit(statevector_mode=sv_mode, parameter=np.ones(var_form_uccsd._num_parameters))
for i in range(len(circuit_uccsd)):
    fig = circuit_uccsd[i].draw(output='mpl')
    show_figure(fig)
    fig.show()
# Out:
# Circuit for: II
# Circuit for: IZ
# Circuit for: ZI
# Circuit for: ZZ
# Circuit for: XX
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# where all single-qubit operations are compiled down the **physical gates**:
# $$U_3(\theta,\phi,\lambda) = \begin{pmatrix} \cos(\theta/2) & -e^{i\lambda}\sin(\theta/2) \\ e^{i\phi}\sin(\theta/2)
# & e^{i\lambda+i\phi}\cos(\theta/2) \end{pmatrix}$$, $$U_1(\lambda) = U_3(0,0,\lambda) = \begin{pmatrix} 1 & 0 \\ 0 & e^{i\lambda} \end{pmatrix}$$, $$U_2(\phi,\lambda) = U_3(\pi/2,\phi,\lambda) = \frac{1}{\sqrt{2}}\begin{pmatrix} 1 & -e^{i\lambda} \\ e^{i\phi} & e^{i\lambda+i\phi} \end{pmatrix}$$
# for example the Hadamard gate is $U_2(0,\pi)$.
#
# We read those graphs from left to right with $\left|q_0q_1\right\rangle$ notation convention.
# Our system requires 2 qubits $q_0$ and $q_1$ reduced from 4 due to two-qubit reduction from the parity mapping.
# The qubits always start to be in the initial state $|0\rangle$.
# Afterwards we act with unitary operations on the qubits.

# %% [markdown]
# ### Hardware-efficient Ansatz
# #### particle-conserving Variational Form

# %% [markdown]
# We can also make a low-depth, particle conserving ansatz (like UCCSD), by using SWAP gates as entanglers to preserve the number of 1's (electrons) in the state.

# %%
circuit_swaprz = vqe_swaprz.construct_circuit(statevector_mode=sv_mode, parameter=np.ones(var_form_swaprz._num_parameters))
circuit_swaprz[1].draw(output='mpl')

# %% [markdown]
# #### particle-non-conserving Variational Form

# %% [markdown]
# By using the CNOTs as entanglers we can get out of the $N_{el}$ Fock subspace and obtain a converged state which can be with different average particle number.

# %%
circuit_ryrz = vqe_ryrz.construct_circuit(statevector_mode=sv_mode, parameter=np.ones(var_form_ryrz._num_parameters))
circuit_ryrz[1].draw(output='mpl')

# %% [markdown]
# ### Step 4: Run VQE algorithm and retrieve the results
# The smallest eigenvalue is stored in the first entry of the `eigvals` key.
#
# Note: Until now we have not done any calculation on the quantum computer. During the next step the algorithm is run on the real device or using the simulator.

# %%
results = vqe_uccsd.run(quantum_instance)
print('The computed ground state energy is: {:.12f}'.format(results['eigvals'][0]))
print('The total ground state energy is: {:.12f}'.format(results['eigvals'][0] + nuclear_repulsion_energy))
print("Parameters: {}".format(results['opt_params']))
# Out:
# 2019-09-09 17:59:59,294:qiskit.aqua.algorithms.adaptive.vq_algorithm:INFO: Starting optimizer.
# bounds=[(-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793)]
# initial point=[0. 0. 0.]
# 2019-09-09 17:59:59,473:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 1 returned -1.212468206771055
# 2019-09-09 17:59:59,642:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 2 returned -1.212468206771055
# 2019-09-09 17:59:59,813:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 3 returned -1.2124682067710548
# 2019-09-09 17:59:59,990:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 4 returned -1.212468202053029
# 2019-09-09 18:00:00,169:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 5 returned -1.3115032151715336
# 2019-09-09 18:00:00,344:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 6 returned -1.3115032151715336
# 2019-09-09 18:00:00,527:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 7 returned -1.3115032151715336
# 2019-09-09 18:00:00,705:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 8 returned -1.3115032160076279
# 2019-09-09 18:00:00,884:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 9 returned -1.314181904919977
# 2019-09-09 18:00:01,063:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 10 returned -1.314181904919977
# 2019-09-09 18:00:01,246:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 11 returned -1.3141819049199766
# 2019-09-09 18:00:01,422:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 12 returned -1.314181904836928
# 2019-09-09 18:00:01,599:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 13 returned -1.3142084856902925
# 2019-09-09 18:00:01,779:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 14 returned -1.3142084856902925
# 2019-09-09 18:00:01,959:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 15 returned -1.3142084856902927
# 2019-09-09 18:00:02,134:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 16 returned -1.3142084856905012
# 2019-09-09 18:00:02,312:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 17 returned -1.3142084858581717
# 2019-09-09 18:00:02,493:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 18 returned -1.3142084858581717
# 2019-09-09 18:00:02,669:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 19 returned -1.3142084858581717
# 2019-09-09 18:00:02,846:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 20 returned -1.314208485858171
# 2019-09-09 18:00:02,848:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Optimization complete in 3.553847074508667 seconds.
# Found opt_params [ 0.00000000e+00 -3.58971974e-08 -4.07180577e-01] in 20 evals
# The computed ground state energy is: -1.314208485858
# The total ground state energy is: -0.983472729033
# Parameters: [ 0.00000000e+00 -3.58971974e-08 -4.07180577e-01]

# %% [markdown]
# The Variational Quantum Eigensolver did arrive at the minimum. As it is a variatonal method we know that we are above the "exact" solution. This is indeed the property which is used, when running the VQE, because we know that every solution we find the one that has a lower energy is better than our previous one.

# %% [markdown]
# ## Go a step further and evolve our system in time

# %% [markdown]
# Now we want to evolve our system in time, starting at an initial state. e.g. the Hartree Fock state, which we also used to start our optimization.

# %%
evolution_time = 100 # how many time steps
num_time_slices = 4 # number of Trotter steps
qr = QuantumRegister(num_qubits,'q')
initial_circuit = HF_state.construct_circuit(mode='circuit')

# %% [markdown]
# Now we time evolve our state with time-evolution operator by exponentiating the `qubitOp` $$e^{-i\hat{H}t} \underbrace{=}_{Trotter}\prod_{n} e^{-i\hat{H}t/n}$$ that is our electronic Hamiltonian and `num_time_slices`$=n$.

# %%
evolution_circuit = qubitOp.evolve(state_in=initial_circuit, evo_time=evolution_time, evo_mode='circuit',num_time_slices=num_time_slices, expansion_mode='trotter')
evolution_circuit.draw(output='mpl')
# Out:
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)

# %% [markdown]
# We also want to run the circuit we just constructed. As a result we get the evolving state vector of the system for different evolution times `evo_time`.

# %%
max_time=evolution_time
statevector_of_t = np.zeros([max_time,2*num_qubits])
for evo_t in range(max_time):
    evolution_circuit = qubitOp.evolve(state_in=initial_circuit, evo_time=evo_t, evo_mode='circuit',num_time_slices=num_time_slices, expansion_mode='trotter')
    result = quantum_instance.execute(evolution_circuit)
    statevector_of_t[evo_t,:] = np.asarray(result.get_statevector(evolution_circuit))
# Out:
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/ipykernel_launcher.py:6: ComplexWarning: Casting complex values to real discards the imaginary part
#
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/qiskit/aqua/operators/weighted_pauli_operator.py:863: DeprecationWarning: evo_mode option is deprecated and it will be removed after 0.6, Every operator knows which mode is using, not need to indicate the mode.
#   DeprecationWarning)

# %% [markdown]
# ### Evolution of the state vector
# Here we will plot the 3 fist entries of the state vector.
# Then we plot their absolute value.

# %%
t = np.linspace(0,max_time-1,max_time)

plt.figure(1)
plt.plot(t,statevector_of_t[:,0],'-r', t,statevector_of_t[:,1],'-b', t,statevector_of_t[:,2],'-g', t,statevector_of_t[:,3],'-y')
plt.xlabel('time of evolution')
plt.ylabel('Re(Statevector[i])')
plt.show()

# absolute values of statevector entries
plt.figure(2)
plt.plot(t,np.abs(statevector_of_t[:,0]),'-r', t,np.abs(statevector_of_t[:,1]),'-b', t,np.abs(statevector_of_t[:,2]),'-g', t,np.abs(statevector_of_t[:,3]),'-y')
plt.xlabel('time of evolution')
plt.ylabel('|Statevector[i]|')
plt.show()

# %% [markdown]
# ### Using Qiskit's visualize
# We can plot the state vector in the density matrix form $\rho =\sum _{j}p_{j}|\psi _{j}\rangle \langle \psi _{j}|$ and see the real and imaginary part of $p_j$ for off-diagonal elements.

# %%
time_min = 0
time_max = 4
for i in range(time_min, time_max):
    fig = plot_state_city(statevector_of_t[i,:])
    show_figure(fig)
    fig.show()
# Out:
# /anaconda3/envs/qiskit_camp/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ##  H2 using declarative approach
# We use this example to show you the declarative approach (provide an input file to qiskit) to solve chemistry problems. But the same is doable in a fully programmatic way (presented so far), especially for those users who are interested in learning the Qiskit Aqua and Qiskit Chemistry APIs as well as contributing new algorithmic components.
#
# It takes the  HDF5 file located at *H2/H2_equilibrium_0.735_sto-3g.hdf5* and reads in the values of integrals. This allows not to recompute them every time and have exactly the same initial data.

# %%
# First, we use classical eigendecomposition to get ground state energy (including nuclear repulsion energy) as reference.
qiskit_chemistry_dict = {
    'driver': {'name': 'HDF5'},
    'HDF5': {'hdf5_input': 'H2/H2_equilibrium_0.735_sto-3g.hdf5'},
    'operator': {'name':'hamiltonian', 
                 'qubit_mapping': 'parity', 
                 'two_qubit_reduction': True},
    'algorithm': {'name': 'ExactEigensolver'}
}
solver = QiskitChemistry()
result_classical = solver.run(qiskit_chemistry_dict)

# Second, we use variational quantum eigensolver (VQE)
qiskit_chemistry_dict['algorithm']['name'] = 'VQE'
qiskit_chemistry_dict['optimizer'] = {'name': 'SPSA', 'max_trials': 350}
qiskit_chemistry_dict['variational_form'] = {'name': 'RYRZ', 'depth': 3, 'entanglement':'full'}
backend = Aer.get_backend('statevector_simulator')
solver = QiskitChemistry()
result = solver.run(qiskit_chemistry_dict, backend=backend)

# We print out the results
print('Ground state energy (classical): {:.12f}'.format(result_classical['energy']))
print('Ground state energy (quantum)  : {:.12f}'.format(result['energy']))
print("====================================================")

# You can also print out other info in the field 'printable'
for line in result['printable']:
    print(line)
# Out:
# 2019-09-09 20:23:09,717:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 20:23:09,718:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 20:23:09,728:qiskit.chemistry.qmolecule:INFO: Originating driver name: PSI4
# 2019-09-09 20:23:09,729:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 20:23:09,729:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# molecule h2 {
#    0 1
#    H  0.0 0.0 -0.3675
#    H  0.0 0.0  0.3675
# }
#
# set {
#   basis sto-3g
#   scf_type pk
#
# 2019-09-09 20:23:09,730:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -1.1169989966131646
# 2019-09-09 20:23:09,731:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.7199689912789116
# 2019-09-09 20:23:09,731:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -1.8369679878920762
# 2019-09-09 20:23:09,732:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 20:23:09,733:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 20:23:09,733:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 20:23:09,733:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 20:23:09,734:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -0.3675000016181253
# 2019-09-09 20:23:09,735:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 0.3675000016181253
# 2019-09-09 20:23:09,735:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 20:23:09,736:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.58062892  0.67633625]
# 2019-09-09 20:23:09,737:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 20:23:09,737:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 20:23:09,738:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 20:23:09,739:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 20:23:09,739:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 20:23:09,741:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 20:23:09,741:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: False
# 2019-09-09 20:23:09,742:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 20:23:11,266:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 20:23:11,576:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 20:23:11,883:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 20:23:11,884:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 20:23:11,909:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# 2019-09-09 20:23:11,973:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 20:23:11,973:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 20:23:11,983:qiskit.chemistry.qmolecule:INFO: Originating driver name: PSI4
# 2019-09-09 20:23:11,983:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 20:23:11,984:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# molecule h2 {
#    0 1
#    H  0.0 0.0 -0.3675
#    H  0.0 0.0  0.3675
# }
#
# set {
#   basis sto-3g
#   scf_type pk
#
# 2019-09-09 20:23:11,984:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -1.1169989966131646
# 2019-09-09 20:23:11,985:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.7199689912789116
# 2019-09-09 20:23:11,986:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -1.8369679878920762
# 2019-09-09 20:23:11,986:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 20:23:11,987:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 20:23:11,987:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 20:23:11,988:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 20:23:11,989:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -0.3675000016181253
# 2019-09-09 20:23:11,989:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 0.3675000016181253
# 2019-09-09 20:23:11,990:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 20:23:11,991:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.58062892  0.67633625]
# 2019-09-09 20:23:11,992:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 20:23:11,993:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 20:23:11,994:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 20:23:11,994:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 20:23:11,996:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 20:23:11,996:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 20:23:11,997:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: False
# 2019-09-09 20:23:11,997:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 20:23:13,518:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 20:23:13,817:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 20:23:14,122:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 20:23:14,124:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 20:23:14,151:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO:
# ==================== Setting of VQE ============================
# Algorithm: VQE
# -- quantum_instance: None
# -- var_form: <qiskit.aqua.components.variational_forms.ryrz.RYRZ object at 0x136b5b908>
# -- optimizer: <qiskit.aqua.components.optimizers.spsa.SPSA object at 0x11b9bed68>
# -- cost_fn: <bound method VQE._energy_evaluation of <qiskit.aqua.algorithms.adaptive.vqe.vqe.VQE object at 0x137b55b00>>
# -- initial_point: Random seed
# -- callback: None
# -- operator: Representation: paulis, qubits: 2, size: 5
# -- eval_count: 0
# -- aux_operators: [<qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x137dd24a8>, <qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x137e0c1d0>, <qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x136b5b208>, <qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x11ba0e588>, <qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x11b99bda0>, <qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x137e06780>]
# -- auto_conversion: True
# ===============================================================
# Variational Form: RYRZ
# -- num_parameters: 16
# -- num_qubits: 2
# -- bounds: [(-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793)]
# -- depth: 3
# -- entangler_map: [[0, 1]]
# -- entangled_qubits: [0, 1]
# -- initial_state: <qiskit.aqua.components.initial_states.zero.Zero object at 0x136a955f8>
# -- entanglement_gate: cz
# -- skip_unentangled_qubits: False
# ===============================================================
# Optimizer: SPSA
# -- gradient_support_level: 1
# -- bounds_support_level: 1
# -- initial_point_support_level: 3
# -- options: {'save_steps': 1, 'last_avg': 1}
# -- max_evals_grouped: 1
# -- max_trials: 350
# -- parameters: [0.62831853 0.1        0.602      0.101      0.        ]
# -- skip_calibration: False
# ===============================================================
# 2019-09-09 20:23:14,152:qiskit.aqua.quantum_instance:INFO:
# Qiskit Terra version: 0.9.0
# Backend: 'statevector_simulator (AerProvider)', with following setting:
# {'basis_gates': ['u1', 'u2', 'u3', 'cx', 'cz', 'cu1', 'id', 'x', 'y', 'z', 'h', 's', 'sdg', 't', 'tdg', 'ccx', 'swap', 'multiplexer', 'snapshot', 'unitary', 'reset', 'initialize'], 'coupling_map': None}
# {'pass_manager': None, 'initial_layout': None, 'seed_transpiler': None, 'optimization_level': None}
# RunConfig(max_credits=10, shots=1)
# {'timeout': None}
# {}
# {}
# Measurement mitigation: None
# 2019-09-09 20:23:14,153:qiskit.aqua.algorithms.adaptive.vq_algorithm:INFO: Starting optimizer.
# bounds=[(-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793)]
# initial point=[-0.51998342 -1.05226934 -0.14455547  1.76525661 -1.56687588 -0.88166986
#  -2.2165827   2.06419499 -2.35353417  1.05808842 -0.79917625 -2.91774819
#   1.95896448 -1.12827061  2.16341074 -0.99764816]
# 2019-09-09 20:23:14,197:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 1 returned -0.9762823859282925
# 2019-09-09 20:23:14,233:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 2 returned -1.091135145185531
# 2019-09-09 20:23:14,268:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 3 returned -0.8838070970794186
# 2019-09-09 20:23:14,304:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 4 returned -1.1768416799328114
# 2019-09-09 20:23:14,337:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 5 returned -1.0334082121937491
# 2019-09-09 20:23:14,374:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 6 returned -1.0916891425231536
# 2019-09-09 20:23:14,409:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 7 returned -1.1145742370332539
# 2019-09-09 20:23:14,444:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 8 returned -0.9980859714203376
# 2019-09-09 20:23:14,482:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 9 returned -1.1173277493593208
# 2019-09-09 20:23:14,520:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 10 returned -0.9623889376391477
# 2019-09-09 20:23:14,560:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 11 returned -1.0399349238831175
# 2019-09-09 20:23:14,598:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 12 returned -1.0474920953511861
# 2019-09-09 20:23:14,635:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 13 returned -1.041314476866334
# 2019-09-09 20:23:14,670:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 14 returned -1.057254940568377
# 2019-09-09 20:23:14,704:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 15 returned -1.1492230750696708
# 2019-09-09 20:23:14,738:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 16 returned -0.9029789873649865
# 2019-09-09 20:23:14,773:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 17 returned -1.1360236583167207
# 2019-09-09 20:23:14,806:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 18 returned -0.9339435861449384
# 2019-09-09 20:23:14,842:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 19 returned -1.0956558083178911
# 2019-09-09 20:23:14,878:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 20 returned -1.0172957029467207
# 2019-09-09 20:23:14,912:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 21 returned -0.970230166898715
# 2019-09-09 20:23:14,947:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 22 returned -1.1136000127065964
# 2019-09-09 20:23:14,984:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 23 returned -0.906347672455052
# 2019-09-09 20:23:15,024:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 24 returned -1.1698303096446392
# 2019-09-09 20:23:15,061:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 25 returned -1.0888288229173686
# 2019-09-09 20:23:15,095:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 26 returned -1.030326254351291
# 2019-09-09 20:23:15,130:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 27 returned -1.2493063165002423
# 2019-09-09 20:23:15,164:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 28 returned -0.8366766595777064
# 2019-09-09 20:23:15,198:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 29 returned -0.9751842615688731
# 2019-09-09 20:23:15,232:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 30 returned -1.15293311031742
# 2019-09-09 20:23:15,268:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 31 returned -1.0172923076630178
# 2019-09-09 20:23:15,303:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 32 returned -1.0719187613348935
# 2019-09-09 20:23:15,337:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 33 returned -0.9399413288946795
# 2019-09-09 20:23:15,370:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 34 returned -1.1806020475518502
# 2019-09-09 20:23:15,405:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 35 returned -0.8776136915778147
# 2019-09-09 20:23:15,439:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 36 returned -1.2295113027554398
# 2019-09-09 20:23:15,473:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 37 returned -1.0661168819649387
# 2019-09-09 20:23:15,507:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 38 returned -1.0210147383283803
# 2019-09-09 20:23:15,542:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 39 returned -1.022118317292917
# 2019-09-09 20:23:15,575:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 40 returned -1.0763465315812395
# 2019-09-09 20:23:15,609:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 41 returned -1.172324715775777
# 2019-09-09 20:23:15,642:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 42 returned -0.9138516336604707
# 2019-09-09 20:23:15,678:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 43 returned -0.9740821771717173
# 2019-09-09 20:23:15,714:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 44 returned -1.1634383032591256
# 2019-09-09 20:23:15,748:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 45 returned -0.9877229019240632
# 2019-09-09 20:23:15,782:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 46 returned -1.0926062305903401
# 2019-09-09 20:23:15,817:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 47 returned -0.9347275188151614
# 2019-09-09 20:23:15,852:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 48 returned -1.1392993021862563
# 2019-09-09 20:23:15,886:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 49 returned -0.9777333413836116
# 2019-09-09 20:23:15,921:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 50 returned -1.1018872155901938
# 2019-09-09 20:23:15,954:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 51 returned -1.112473648895371
# 2019-09-09 20:23:15,988:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 52 returned -0.9715637795262142
# 2019-09-09 20:23:16,023:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 53 returned -0.8719257195594725
# 2019-09-09 20:23:16,058:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 54 returned -0.8483807826487941
# 2019-09-09 20:23:16,201:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 55 returned -0.9476897972824124
# 2019-09-09 20:23:16,238:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 56 returned -0.788405055911626
# 2019-09-09 20:23:16,274:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 57 returned -1.1461043739956058
# 2019-09-09 20:23:16,309:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 58 returned -1.258730802072696
# 2019-09-09 20:23:16,343:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 59 returned -1.1209101443389782
# 2019-09-09 20:23:16,378:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 60 returned -1.4037635222888958
# 2019-09-09 20:23:16,412:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 61 returned -1.197264679523381
# 2019-09-09 20:23:16,448:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 62 returned -1.238081710932473
# 2019-09-09 20:23:16,483:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 63 returned -1.2217490288957973
# 2019-09-09 20:23:16,519:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 64 returned -1.2307972593179661
# 2019-09-09 20:23:16,554:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 65 returned -1.208820273363671
# 2019-09-09 20:23:16,590:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 66 returned -1.2692743033842804
# 2019-09-09 20:23:16,626:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 67 returned -1.253671523779191
# 2019-09-09 20:23:16,661:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 68 returned -1.2764905108993763
# 2019-09-09 20:23:16,697:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 69 returned -1.2629366825442403
# 2019-09-09 20:23:16,732:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 70 returned -1.2931736743382296
# 2019-09-09 20:23:16,767:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 71 returned -1.3510331160516094
# 2019-09-09 20:23:16,803:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 72 returned -1.2076077285673394
# 2019-09-09 20:23:16,838:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 73 returned -1.4887322403635086
# 2019-09-09 20:23:16,872:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 74 returned -1.3184926195949294
# 2019-09-09 20:23:16,907:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 75 returned -1.5310913878307864
# 2019-09-09 20:23:16,943:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 76 returned -1.5336446812385185
# 2019-09-09 20:23:16,978:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 77 returned -1.562267200292853
# 2019-09-09 20:23:17,011:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 78 returned -1.4263313819476968
# 2019-09-09 20:23:17,048:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 79 returned -1.4500494493551725
# 2019-09-09 20:23:17,084:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 80 returned -1.5532319032657944
# 2019-09-09 20:23:17,119:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 81 returned -1.473623706881725
# 2019-09-09 20:23:17,155:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 82 returned -1.6226184417168437
# 2019-09-09 20:23:17,190:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 83 returned -1.7070954032828372
# 2019-09-09 20:23:17,226:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 84 returned -1.602598540489309
# 2019-09-09 20:23:17,262:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 85 returned -1.7063189812892188
# 2019-09-09 20:23:17,298:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 86 returned -1.7022415597040537
# 2019-09-09 20:23:17,336:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 87 returned -1.7385911859639103
# 2019-09-09 20:23:17,374:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 88 returned -1.6793490541382528
# 2019-09-09 20:23:17,415:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 89 returned -1.7515922074245518
# 2019-09-09 20:23:17,453:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 90 returned -1.6544684205453515
# 2019-09-09 20:23:17,491:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 91 returned -1.7537778034324403
# 2019-09-09 20:23:17,527:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 92 returned -1.7245677327141204
# 2019-09-09 20:23:17,561:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 93 returned -1.756098620296625
# 2019-09-09 20:23:17,597:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 94 returned -1.7223841768073453
# 2019-09-09 20:23:17,632:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 95 returned -1.7762190655498022
# 2019-09-09 20:23:17,668:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 96 returned -1.7164225447139576
# 2019-09-09 20:23:17,704:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 97 returned -1.776974314633385
# 2019-09-09 20:23:17,740:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 98 returned -1.7357986065168804
# 2019-09-09 20:23:17,775:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 99 returned -1.7473797811137204
# 2019-09-09 20:23:17,810:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 100 returned -1.7844586334646193
# 2019-09-09 20:23:17,845:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 101 returned -1.7750222881542452
# 2019-09-09 20:23:17,882:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 102 returned -1.7544833188284543
# 2019-09-09 20:23:17,919:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 103 returned -1.815605297601913
# 2019-09-09 20:23:17,957:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 104 returned -1.7449620467086526
# 2019-09-09 20:23:17,995:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 105 returned -1.7883706992211024
# 2019-09-09 20:23:18,029:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 106 returned -1.811285680631795
# 2019-09-09 20:23:18,066:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 107 returned -1.8044036915523671
# 2019-09-09 20:23:18,101:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 108 returned -1.8104787453165212
# 2019-09-09 20:23:18,136:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 109 returned -1.7740906918455108
# 2019-09-09 20:23:18,171:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 110 returned -1.8333506195088816
# 2019-09-09 20:23:18,206:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 111 returned -1.8378394814393617
# 2019-09-09 20:23:18,241:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 112 returned -1.793985681300637
# 2019-09-09 20:23:18,275:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 113 returned -1.8339919777193903
# 2019-09-09 20:23:18,310:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 114 returned -1.8034847185187928
# 2019-09-09 20:23:18,345:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 115 returned -1.8071367332835546
# 2019-09-09 20:23:18,380:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 116 returned -1.8376426379409663
# 2019-09-09 20:23:18,414:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 117 returned -1.8460899557540342
# 2019-09-09 20:23:18,450:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 118 returned -1.8000341407321807
# 2019-09-09 20:23:18,486:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 119 returned -1.8504404933507854
# 2019-09-09 20:23:18,520:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 120 returned -1.8363108032462272
# 2019-09-09 20:23:18,556:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 121 returned -1.831849901846813
# 2019-09-09 20:23:18,591:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 122 returned -1.821392407654896
# 2019-09-09 20:23:18,627:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 123 returned -1.845766678209439
# 2019-09-09 20:23:18,662:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 124 returned -1.8329072385924123
# 2019-09-09 20:23:18,698:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 125 returned -1.8251550552621543
# 2019-09-09 20:23:18,732:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 126 returned -1.829098897925556
# 2019-09-09 20:23:18,767:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 127 returned -1.8110837005059666
# 2019-09-09 20:23:18,803:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 128 returned -1.8391270701797062
# 2019-09-09 20:23:18,837:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 129 returned -1.8150444428188486
# 2019-09-09 20:23:18,872:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 130 returned -1.839825498383208
# 2019-09-09 20:23:18,908:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 131 returned -1.84057490494082
# 2019-09-09 20:23:18,944:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 132 returned -1.8472519121882052
# 2019-09-09 20:23:18,979:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 133 returned -1.8435040577483928
# 2019-09-09 20:23:19,013:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 134 returned -1.835167759738686
# 2019-09-09 20:23:19,049:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 135 returned -1.8315438385742306
# 2019-09-09 20:23:19,083:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 136 returned -1.8362272540249351
# 2019-09-09 20:23:19,118:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 137 returned -1.853470006739045
# 2019-09-09 20:23:19,154:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 138 returned -1.8410323173432708
# 2019-09-09 20:23:19,286:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 139 returned -1.8503534029682234
# 2019-09-09 20:23:19,323:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 140 returned -1.8470961757227056
# 2019-09-09 20:23:19,361:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 141 returned -1.844202369812528
# 2019-09-09 20:23:19,398:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 142 returned -1.8195812888986194
# 2019-09-09 20:23:19,434:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 143 returned -1.8522830976301647
# 2019-09-09 20:23:19,470:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 144 returned -1.8524496523879521
# 2019-09-09 20:23:19,504:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 145 returned -1.8419934038922297
# 2019-09-09 20:23:19,541:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 146 returned -1.8364244226010267
# 2019-09-09 20:23:19,578:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 147 returned -1.8255058788619767
# 2019-09-09 20:23:19,618:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 148 returned -1.8397586559114105
# 2019-09-09 20:23:19,657:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 149 returned -1.8451506426368447
# 2019-09-09 20:23:19,697:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 150 returned -1.8447462276083373
# 2019-09-09 20:23:19,737:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 151 returned -1.8380041289383255
# 2019-09-09 20:23:19,777:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 152 returned -1.8428291848867826
# 2019-09-09 20:23:19,816:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 153 returned -1.8449204127542085
# 2019-09-09 20:23:19,853:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 154 returned -1.8520212158842242
# 2019-09-09 20:23:19,889:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 155 returned -1.8409844154113233
# 2019-09-09 20:23:19,924:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 156 returned -1.8278548424897336
# 2019-09-09 20:23:19,959:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 157 returned -1.8382667206710077
# 2019-09-09 20:23:19,994:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 158 returned -1.843135322345501
# 2019-09-09 20:23:20,029:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 159 returned -1.8467056192388402
# 2019-09-09 20:23:20,064:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 160 returned -1.8424473936161212
# 2019-09-09 20:23:20,099:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 161 returned -1.8448365907461604
# 2019-09-09 20:23:20,133:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 162 returned -1.8509199635345042
# 2019-09-09 20:23:20,167:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 163 returned -1.847308018878058
# 2019-09-09 20:23:20,202:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 164 returned -1.8497874653042123
# 2019-09-09 20:23:20,236:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 165 returned -1.8374253796291524
# 2019-09-09 20:23:20,271:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 166 returned -1.836862091209603
# 2019-09-09 20:23:20,306:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 167 returned -1.8440957968888338
# 2019-09-09 20:23:20,341:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 168 returned -1.8441993064124214
# 2019-09-09 20:23:20,375:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 169 returned -1.8500523423837094
# 2019-09-09 20:23:20,410:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 170 returned -1.8455508456835341
# 2019-09-09 20:23:20,444:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 171 returned -1.8434320085520242
# 2019-09-09 20:23:20,478:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 172 returned -1.847368327695594
# 2019-09-09 20:23:20,512:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 173 returned -1.8475798946066992
# 2019-09-09 20:23:20,548:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 174 returned -1.8504469315618366
# 2019-09-09 20:23:20,581:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 175 returned -1.8472715966381097
# 2019-09-09 20:23:20,617:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 176 returned -1.8450236815111223
# 2019-09-09 20:23:20,653:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 177 returned -1.837913791775073
# 2019-09-09 20:23:20,690:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 178 returned -1.8359137173676812
# 2019-09-09 20:23:20,729:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 179 returned -1.8501626054211464
# 2019-09-09 20:23:20,765:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 180 returned -1.8508265906329135
# 2019-09-09 20:23:20,804:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 181 returned -1.8528547914169098
# 2019-09-09 20:23:20,845:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 182 returned -1.8515385539871148
# 2019-09-09 20:23:20,887:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 183 returned -1.8528442817090862
# 2019-09-09 20:23:20,927:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 184 returned -1.8553121576559228
# 2019-09-09 20:23:20,968:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 185 returned -1.8482116983114136
# 2019-09-09 20:23:21,007:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 186 returned -1.8477535388185555
# 2019-09-09 20:23:21,045:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 187 returned -1.8495645532362863
# 2019-09-09 20:23:21,080:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 188 returned -1.850190437146136
# 2019-09-09 20:23:21,115:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 189 returned -1.8419755970397453
# 2019-09-09 20:23:21,150:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 190 returned -1.8409617307472275
# 2019-09-09 20:23:21,186:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 191 returned -1.8499911034725052
# 2019-09-09 20:23:21,221:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 192 returned -1.8501638216806278
# 2019-09-09 20:23:21,255:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 193 returned -1.8499078455206523
# 2019-09-09 20:23:21,290:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 194 returned -1.8492306078566005
# 2019-09-09 20:23:21,325:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 195 returned -1.8507703503949746
# 2019-09-09 20:23:21,361:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 196 returned -1.8494909540674702
# 2019-09-09 20:23:21,395:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 197 returned -1.851901002147411
# 2019-09-09 20:23:21,430:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 198 returned -1.8522275631060168
# 2019-09-09 20:23:21,464:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 199 returned -1.8424915347909778
# 2019-09-09 20:23:21,501:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 200 returned -1.8364277138991563
# 2019-09-09 20:23:21,536:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 201 returned -1.8559962175120561
# 2019-09-09 20:23:21,571:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 202 returned -1.8562871050158256
# 2019-09-09 20:23:21,606:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 203 returned -1.8516490443482878
# 2019-09-09 20:23:21,643:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 204 returned -1.8507507039899724
# 2019-09-09 20:23:21,684:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 205 returned -1.8479217439415419
# 2019-09-09 20:23:21,722:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 206 returned -1.8481676964786997
# 2019-09-09 20:23:21,762:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 207 returned -1.8467097062212716
# 2019-09-09 20:23:21,800:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 208 returned -1.8435386441823247
# 2019-09-09 20:23:21,838:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 209 returned -1.8554012943316098
# 2019-09-09 20:23:21,875:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 210 returned -1.8549045719603388
# 2019-09-09 20:23:21,913:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 211 returned -1.8471719880415218
# 2019-09-09 20:23:21,948:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 212 returned -1.8482720885457617
# 2019-09-09 20:23:21,983:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 213 returned -1.8468963053789684
# 2019-09-09 20:23:22,018:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 214 returned -1.846410152897585
# 2019-09-09 20:23:22,054:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 215 returned -1.835686560408085
# 2019-09-09 20:23:22,089:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 216 returned -1.8360009313782322
# 2019-09-09 20:23:22,124:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 217 returned -1.8387949769698433
# 2019-09-09 20:23:22,160:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 218 returned -1.8426077846692852
# 2019-09-09 20:23:22,198:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 219 returned -1.8533629706898274
# 2019-09-09 20:23:22,236:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 220 returned -1.852964085865483
# 2019-09-09 20:23:22,274:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 221 returned -1.8547918122312117
# 2019-09-09 20:23:22,311:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 222 returned -1.8542026391818558
# 2019-09-09 20:23:22,441:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 223 returned -1.8538247600823254
# 2019-09-09 20:23:22,479:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 224 returned -1.8537350081404607
# 2019-09-09 20:23:22,517:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 225 returned -1.8498768260067442
# 2019-09-09 20:23:22,554:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 226 returned -1.84871863959192
# 2019-09-09 20:23:22,591:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 227 returned -1.8403788433248838
# 2019-09-09 20:23:22,627:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 228 returned -1.8427854575704101
# 2019-09-09 20:23:22,664:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 229 returned -1.8463000733512795
# 2019-09-09 20:23:22,700:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 230 returned -1.8482925888717754
# 2019-09-09 20:23:22,737:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 231 returned -1.847346151115681
# 2019-09-09 20:23:22,774:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 232 returned -1.8493074198887327
# 2019-09-09 20:23:22,811:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 233 returned -1.8506273675881149
# 2019-09-09 20:23:22,846:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 234 returned -1.8500514489440627
# 2019-09-09 20:23:22,885:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 235 returned -1.833808564369991
# 2019-09-09 20:23:22,922:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 236 returned -1.8356273857235517
# 2019-09-09 20:23:22,963:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 237 returned -1.8451055411552602
# 2019-09-09 20:23:23,003:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 238 returned -1.8451401535392122
# 2019-09-09 20:23:23,042:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 239 returned -1.8459044018331205
# 2019-09-09 20:23:23,081:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 240 returned -1.8441024038439642
# 2019-09-09 20:23:23,118:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 241 returned -1.8466336875899927
# 2019-09-09 20:23:23,156:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 242 returned -1.8472458729705643
# 2019-09-09 20:23:23,195:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 243 returned -1.849929845639143
# 2019-09-09 20:23:23,234:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 244 returned -1.8496072342550136
# 2019-09-09 20:23:23,273:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 245 returned -1.8510025268809893
# 2019-09-09 20:23:23,311:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 246 returned -1.8513086647416668
# 2019-09-09 20:23:23,348:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 247 returned -1.8467701950667097
# 2019-09-09 20:23:23,384:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 248 returned -1.847412281849991
# 2019-09-09 20:23:23,420:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 249 returned -1.8508597779093843
# 2019-09-09 20:23:23,455:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 250 returned -1.8500442962074943
# 2019-09-09 20:23:23,490:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 251 returned -1.8353596975886137
# 2019-09-09 20:23:23,526:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 252 returned -1.8344893057795981
# 2019-09-09 20:23:23,566:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 253 returned -1.8483978012486242
# 2019-09-09 20:23:23,603:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 254 returned -1.844673676505482
# 2019-09-09 20:23:23,641:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 255 returned -1.842382329942609
# 2019-09-09 20:23:23,676:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 256 returned -1.8431341623965787
# 2019-09-09 20:23:23,711:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 257 returned -1.8512733512467172
# 2019-09-09 20:23:23,746:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 258 returned -1.852720671360459
# 2019-09-09 20:23:23,782:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 259 returned -1.842642197135307
# 2019-09-09 20:23:23,819:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 260 returned -1.843112012365775
# 2019-09-09 20:23:23,857:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 261 returned -1.8508246630419005
# 2019-09-09 20:23:23,895:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 262 returned -1.852514125565415
# 2019-09-09 20:23:23,931:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 263 returned -1.8457901762763391
# 2019-09-09 20:23:23,967:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 264 returned -1.8454923445051905
# 2019-09-09 20:23:24,002:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 265 returned -1.8304372505828606
# 2019-09-09 20:23:24,037:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 266 returned -1.8303822176627724
# 2019-09-09 20:23:24,073:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 267 returned -1.8525506024367564
# 2019-09-09 20:23:24,108:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 268 returned -1.8523714608576938
# 2019-09-09 20:23:24,144:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 269 returned -1.847721347537509
# 2019-09-09 20:23:24,178:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 270 returned -1.8470751883909058
# 2019-09-09 20:23:24,215:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 271 returned -1.8459807186338923
# 2019-09-09 20:23:24,252:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 272 returned -1.8467830234524676
# 2019-09-09 20:23:24,289:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 273 returned -1.856076656506389
# 2019-09-09 20:23:24,325:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 274 returned -1.8554015395999368
# 2019-09-09 20:23:24,362:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 275 returned -1.842030253846438
# 2019-09-09 20:23:24,396:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 276 returned -1.8439862561144904
# 2019-09-09 20:23:24,432:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 277 returned -1.8302930416304881
# 2019-09-09 20:23:24,467:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 278 returned -1.829776046395591
# 2019-09-09 20:23:24,503:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 279 returned -1.8481974217181605
# 2019-09-09 20:23:24,540:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 280 returned -1.8484104167872721
# 2019-09-09 20:23:24,574:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 281 returned -1.8461017573267644
# 2019-09-09 20:23:24,609:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 282 returned -1.8457045987912504
# 2019-09-09 20:23:24,647:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 283 returned -1.8417197140832076
# 2019-09-09 20:23:24,686:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 284 returned -1.8416659274324643
# 2019-09-09 20:23:24,723:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 285 returned -1.8492949191611667
# 2019-09-09 20:23:24,760:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 286 returned -1.8482304091287705
# 2019-09-09 20:23:24,794:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 287 returned -1.8495788829027406
# 2019-09-09 20:23:24,828:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 288 returned -1.8499482431724463
# 2019-09-09 20:23:24,866:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 289 returned -1.852205154998119
# 2019-09-09 20:23:24,902:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 290 returned -1.8531133478260167
# 2019-09-09 20:23:24,938:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 291 returned -1.8462289872961934
# 2019-09-09 20:23:24,973:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 292 returned -1.846866168813256
# 2019-09-09 20:23:25,009:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 293 returned -1.8488077356424415
# 2019-09-09 20:23:25,045:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 294 returned -1.8508942654430924
# 2019-09-09 20:23:25,082:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 295 returned -1.8494987844984947
# 2019-09-09 20:23:25,119:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 296 returned -1.8491061164837164
# 2019-09-09 20:23:25,156:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 297 returned -1.8467177112677362
# 2019-09-09 20:23:25,194:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 298 returned -1.8473638981795204
# 2019-09-09 20:23:25,230:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 299 returned -1.8456237389736587
# 2019-09-09 20:23:25,267:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 300 returned -1.8461453445198555
# 2019-09-09 20:23:25,303:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 301 returned -1.8501419540535455
# 2019-09-09 20:23:25,430:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 302 returned -1.8487938064679714
# 2019-09-09 20:23:25,468:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 303 returned -1.8441165493225595
# 2019-09-09 20:23:25,505:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 304 returned -1.8433977682168805
# 2019-09-09 20:23:25,541:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 305 returned -1.8433379449060097
# 2019-09-09 20:23:25,579:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 306 returned -1.843653177196907
# 2019-09-09 20:23:25,616:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 307 returned -1.8523317827601444
# 2019-09-09 20:23:25,653:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 308 returned -1.8526879860116419
# 2019-09-09 20:23:25,691:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 309 returned -1.8532312357699716
# 2019-09-09 20:23:25,729:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 310 returned -1.8526425062736935
# 2019-09-09 20:23:25,764:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 311 returned -1.8450621691495794
# 2019-09-09 20:23:25,800:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 312 returned -1.845265255927249
# 2019-09-09 20:23:25,836:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 313 returned -1.8490752976177662
# 2019-09-09 20:23:25,871:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 314 returned -1.8479669261945768
# ...
# 2019-09-09 20:23:37,305:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 631 returned -1.8504043283323603
# 2019-09-09 20:23:37,333:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 632 returned -1.8508446068772437
# 2019-09-09 20:23:37,455:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 633 returned -1.8490570920181917
# 2019-09-09 20:23:37,494:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 634 returned -1.8493362790756183
# 2019-09-09 20:23:37,528:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 635 returned -1.8482850663375423
# 2019-09-09 20:23:37,558:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 636 returned -1.8481154722305975
# 2019-09-09 20:23:37,585:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 637 returned -1.8486068767069497
# 2019-09-09 20:23:37,626:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 638 returned -1.849269837256949
# 2019-09-09 20:23:37,669:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 639 returned -1.8540501196090446
# 2019-09-09 20:23:37,717:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 640 returned -1.8531262223946305
# 2019-09-09 20:23:37,754:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 641 returned -1.8454562077580245
# 2019-09-09 20:23:37,792:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 642 returned -1.8457799364894765
# 2019-09-09 20:23:37,830:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 643 returned -1.845587286662153
# 2019-09-09 20:23:37,864:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 644 returned -1.844172835075922
# 2019-09-09 20:23:37,897:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 645 returned -1.8485919518944354
# 2019-09-09 20:23:37,927:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 646 returned -1.8486210483153729
# 2019-09-09 20:23:37,955:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 647 returned -1.8458907943281841
# 2019-09-09 20:23:37,983:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 648 returned -1.847289598719377
# 2019-09-09 20:23:38,012:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 649 returned -1.84276803976949
# 2019-09-09 20:23:38,042:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 650 returned -1.8403679739513013
# 2019-09-09 20:23:38,070:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 651 returned -1.8460334626390291
# 2019-09-09 20:23:38,097:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 652 returned -1.8488081621826824
# 2019-09-09 20:23:38,125:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 653 returned -1.8496850413921544
# 2019-09-09 20:23:38,152:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 654 returned -1.851117562850553
# 2019-09-09 20:23:38,180:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 655 returned -1.8471916054203494
# 2019-09-09 20:23:38,208:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 656 returned -1.8473176775103795
# 2019-09-09 20:23:38,235:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 657 returned -1.8454894951092538
# 2019-09-09 20:23:38,262:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 658 returned -1.8472139614816636
# 2019-09-09 20:23:38,290:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 659 returned -1.8517392970518654
# 2019-09-09 20:23:38,317:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 660 returned -1.8515304188537016
# 2019-09-09 20:23:38,345:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 661 returned -1.8488169715590856
# 2019-09-09 20:23:38,373:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 662 returned -1.8479840695515097
# 2019-09-09 20:23:38,401:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 663 returned -1.8442659748617902
# 2019-09-09 20:23:38,429:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 664 returned -1.8451676965253663
# 2019-09-09 20:23:38,457:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 665 returned -1.8534969838175919
# 2019-09-09 20:23:38,485:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 666 returned -1.85317484653357
# 2019-09-09 20:23:38,512:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 667 returned -1.8442354923488689
# 2019-09-09 20:23:38,541:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 668 returned -1.844588127200039
# 2019-09-09 20:23:38,569:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 669 returned -1.8534189075963043
# 2019-09-09 20:23:38,596:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 670 returned -1.8529881682873532
# 2019-09-09 20:23:38,624:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 671 returned -1.8420169145565115
# 2019-09-09 20:23:38,651:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 672 returned -1.8437736114155545
# 2019-09-09 20:23:38,679:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 673 returned -1.8378400800228358
# 2019-09-09 20:23:38,706:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 674 returned -1.8386035570145711
# 2019-09-09 20:23:38,734:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 675 returned -1.83945194231689
# 2019-09-09 20:23:38,762:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 676 returned -1.8425815072631764
# 2019-09-09 20:23:38,790:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 677 returned -1.8462964835268385
# 2019-09-09 20:23:38,817:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 678 returned -1.846859654684377
# 2019-09-09 20:23:38,844:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 679 returned -1.8455202400855422
# 2019-09-09 20:23:38,872:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 680 returned -1.8455111939111746
# 2019-09-09 20:23:38,899:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 681 returned -1.849310013378873
# 2019-09-09 20:23:38,927:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 682 returned -1.8490920178151704
# 2019-09-09 20:23:38,954:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 683 returned -1.8396525475278904
# 2019-09-09 20:23:38,982:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 684 returned -1.838201724740866
# 2019-09-09 20:23:39,011:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 685 returned -1.8522477131724164
# 2019-09-09 20:23:39,039:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 686 returned -1.8507860452231093
# 2019-09-09 20:23:39,069:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 687 returned -1.849016389713419
# 2019-09-09 20:23:39,097:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 688 returned -1.8488806175232326
# 2019-09-09 20:23:39,124:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 689 returned -1.8537940847074175
# 2019-09-09 20:23:39,152:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 690 returned -1.8536966742694003
# 2019-09-09 20:23:39,179:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 691 returned -1.8484772600790462
# 2019-09-09 20:23:39,207:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 692 returned -1.848326297830041
# 2019-09-09 20:23:39,236:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 693 returned -1.8398617489542843
# 2019-09-09 20:23:39,265:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 694 returned -1.8405353358121848
# 2019-09-09 20:23:39,298:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 695 returned -1.8513158118554978
# 2019-09-09 20:23:39,333:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 696 returned -1.8504029310305934
# 2019-09-09 20:23:39,368:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 697 returned -1.8503368209816091
# 2019-09-09 20:23:39,403:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 698 returned -1.8504718136406402
# 2019-09-09 20:23:39,437:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 699 returned -1.853255699385611
# 2019-09-09 20:23:39,470:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 700 returned -1.8531191894377839
# 2019-09-09 20:23:39,504:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 701 returned -1.846628138868394
# 2019-09-09 20:23:39,538:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 702 returned -1.8477087222525417
# 2019-09-09 20:23:39,572:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 703 returned -1.8449107834489546
# 2019-09-09 20:23:39,603:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 704 returned -1.8453906266402453
# 2019-09-09 20:23:39,632:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 705 returned -1.850333010714208
# 2019-09-09 20:23:39,660:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 706 returned -1.8502586651063473
# 2019-09-09 20:23:39,691:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 707 returned -1.8512548821663521
# 2019-09-09 20:23:39,723:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 708 returned -1.851985480355699
# 2019-09-09 20:23:39,757:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 709 returned -1.8498649559057043
# 2019-09-09 20:23:39,791:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 710 returned -1.8498977979538447
# 2019-09-09 20:23:39,825:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 711 returned -1.854269945308665
# 2019-09-09 20:23:39,860:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 712 returned -1.8540885810008525
# 2019-09-09 20:23:39,892:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 713 returned -1.845325142296482
# 2019-09-09 20:23:39,923:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 714 returned -1.8455989635220118
# 2019-09-09 20:23:39,952:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 715 returned -1.8515003683961901
# 2019-09-09 20:23:39,984:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 716 returned -1.851727372364619
# 2019-09-09 20:23:40,108:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 717 returned -1.8494000159221413
# 2019-09-09 20:23:40,147:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 718 returned -1.8494482924682143
# 2019-09-09 20:23:40,183:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 719 returned -1.8479952932048849
# 2019-09-09 20:23:40,217:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 720 returned -1.8490276256878633
# 2019-09-09 20:23:40,250:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 721 returned -1.8524353401484313
# 2019-09-09 20:23:40,284:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 722 returned -1.8516561627384354
# 2019-09-09 20:23:40,318:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 723 returned -1.8480259971532083
# 2019-09-09 20:23:40,354:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 724 returned -1.847759655829523
# 2019-09-09 20:23:40,391:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 725 returned -1.8435088724788276
# 2019-09-09 20:23:40,426:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 726 returned -1.8425980229084105
# 2019-09-09 20:23:40,463:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 727 returned -1.850743512383854
# 2019-09-09 20:23:40,499:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 728 returned -1.8513361114820033
# 2019-09-09 20:23:40,535:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 729 returned -1.8521681147083855
# 2019-09-09 20:23:40,572:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 730 returned -1.8526644433623485
# 2019-09-09 20:23:40,608:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 731 returned -1.8449175791851888
# 2019-09-09 20:23:40,644:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 732 returned -1.8442373702820392
# 2019-09-09 20:23:40,681:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 733 returned -1.8433308048400852
# 2019-09-09 20:23:40,718:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 734 returned -1.844585148992738
# 2019-09-09 20:23:40,753:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 735 returned -1.8468485755880362
# 2019-09-09 20:23:40,789:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 736 returned -1.8469949149977636
# 2019-09-09 20:23:40,825:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 737 returned -1.8506804712544522
# 2019-09-09 20:23:40,859:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 738 returned -1.8505881567137192
# 2019-09-09 20:23:40,891:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 739 returned -1.851193663815514
# 2019-09-09 20:23:40,926:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 740 returned -1.8522762278147176
# 2019-09-09 20:23:40,954:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 741 returned -1.8444361979676724
# 2019-09-09 20:23:40,983:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 742 returned -1.8429199504057365
# 2019-09-09 20:23:41,013:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 743 returned -1.8480354086718402
# 2019-09-09 20:23:41,048:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 744 returned -1.8486917596277486
# 2019-09-09 20:23:41,084:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 745 returned -1.8512740556840281
# 2019-09-09 20:23:41,120:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 746 returned -1.8507509157464916
# 2019-09-09 20:23:41,157:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 747 returned -1.8529344820277411
# 2019-09-09 20:23:41,193:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 748 returned -1.8528702135761796
# 2019-09-09 20:23:41,229:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 749 returned -1.8463028664662215
# 2019-09-09 20:23:41,264:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 750 returned -1.8456855590496117
# 2019-09-09 20:23:41,295:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 751 returned -1.8572688599602767
# 2019-09-09 20:23:41,296:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Optimization complete in 27.143129110336304 seconds.
# Found opt_params [-0.72164534  0.59019111 -0.93153829 -0.2558359  -2.07279861  0.15212968
#  -2.81189988  1.94985893 -3.9177481   0.48526353  0.29510475 -2.12230989
#   1.83736739 -1.09353592  2.57407138 -1.76813887] in 751 evals
# 2019-09-09 20:23:41,498:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# Ground state energy (classical): -1.137306035753
# Ground state energy (quantum)  : -1.137299868681
# ====================================================
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -1.85726885996
#   - computed part:      -1.85726885996
#   - frozen energy part: 0.0
#   - particle hole part: 0.0
# ~ Nuclear repulsion energy (Hartree): 0.719968991279
# > Total ground state energy (Hartree): -1.137299868681
#   Measured:: Num particles: 2.000, S: 0.000, M: 0.00000
#
# === DIPOLE MOMENT ===
#
# * Electronic dipole moment (a.u.): [0.0  0.0  -0.00322421]
#   - computed part:      [0.0  0.0  -0.00322421]
#   - frozen energy part: [0.0  0.0  0.0]
#   - particle hole part: [0.0  0.0  0.0]
# ~ Nuclear dipole moment (a.u.): [0.0  0.0  0.0]
# > Dipole moment (a.u.): [0.0  0.0  -0.00322421]  Total: 0.00322421
#                (debye): [0.0  0.0  -0.00819512]  Total: 0.00819512

# %% [markdown]
# ## Declarative approach : optimizing the potential energy surface
#
# The optimization considered previously is now performed for a molecule H$_2$ for different interatomic distances, and the corresponding nuclei Coulomb repulsion is added in order to obtain a potential energy surface.

# %%
molecule='H2'
maxiter = 10 # increase to allow optimizer to converge, set low to test
mol_distances = np.arange(0.2, 3.1, 0.2)
mol_distances_vqe = np.arange(0.2, 3.1,1)

# Exact eigensolver
qiskit_chemistry_dict_ee = {
    'driver': {'name': 'HDF5'},
    'HDF5': {'hdf5_input': ''},
    'operator': {'name':'hamiltonian', 
                 'qubit_mapping': 'parity', 
                 'two_qubit_reduction': True},
    'algorithm': {'name': 'ExactEigensolver'}
}

# choose which backend want to use
# backend = Aer.get_backend('qasm_simulator')
backend = Aer.get_backend('statevector_simulator')

# VQE
qiskit_chemistry_dict_vqe = {
    'driver': {'name': 'HDF5'},
    'HDF5': {'hdf5_input': ''},
    'operator': {'name':'hamiltonian', 
                 'qubit_mapping': 'parity', 
                 'two_qubit_reduction': True},
    'algorithm': {'name': 'VQE'},
    'optimizer': {'name': 'L_BFGS_B', 'maxiter': maxiter}, # or SPSA, max_trials=200
    'variational_form': {'name': 'RY', 'depth': 1, 'entanglement':'full'}, # RYRZ, UCCSD (delete entanglement field)
    'backend': {'shots': 1024}
}

algos = ['ExactEigensolver', 'VQE']
energy = np.zeros((len(algos), len(mol_distances)))
energy_vqe = np.zeros((len(algos), len(mol_distances_vqe)))

# Run the algos
for j, algo in enumerate([qiskit_chemistry_dict_ee, qiskit_chemistry_dict_vqe]):
    algo_name = algo['algorithm']['name']
    print("Using {}".format(algo_name))
    if algo_name == 'VQE':
        for i, dis in enumerate(mol_distances_vqe):
            print("Processing atomic distance: {:1.1f} Angstrom".format(dis), end='\r')
            algo['HDF5']['hdf5_input'] = "{}/{:1.1f}_sto-3g.hdf5".format(molecule, dis)
            result = solver.run(algo, backend=backend if algo_name == 'VQE' else None)
            energy_vqe[j][i] = result['energy']
    else:
        for i, dis in enumerate(mol_distances):
            print("Processing atomic distance: {:1.1f} Angstrom".format(dis), end='\r')
            algo['HDF5']['hdf5_input'] = "{}/{:1.1f}_sto-3g.hdf5".format(molecule, dis)
            result = solver.run(algo, backend=backend if algo_name == 'VQE' else None)
            energy[j][i] = result['energy']
# Out:
# 2019-09-09 22:25:46,573:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:46,574:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:46,583:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:46,584:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:46,585:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -0.1; H .0 .0 0.1
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:46,585:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: 0.16417501206169582
# 2019-09-09 22:25:46,586:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 2.6458860546
# 2019-09-09 22:25:46,586:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -2.481711042538304
# 2019-09-09 22:25:46,587:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:46,587:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:46,588:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:46,589:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:46,589:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -0.1
# 2019-09-09 22:25:46,590:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 0.1
# 2019-09-09 22:25:46,590:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:46,591:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.85882453  1.57236203]
# 2019-09-09 22:25:46,591:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:46,593:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:46,594:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:46,594:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:46,595:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:46,596:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:46,596:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:46,597:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:46,723:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:46,724:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:46,733:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:46,733:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# Using ExactEigensolver
# Processing atomic distance: 0.2 Angstrom
# 2019-09-09 22:25:46,752:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# 2019-09-09 22:25:46,773:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:46,773:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:46,783:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:46,784:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:46,785:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -0.20000000000000004; H .0 .0 0.20000000000000004
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:46,785:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -0.9043613941635396
# 2019-09-09 22:25:46,786:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 1.3229430272999998
# 2019-09-09 22:25:46,786:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -2.2273044214635394
# 2019-09-09 22:25:46,787:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:46,787:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:46,788:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:46,789:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:46,789:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -0.20000000000000004
# 2019-09-09 22:25:46,790:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 0.20000000000000004
# 2019-09-09 22:25:46,791:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:46,792:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.74521253  1.1674164 ]
# 2019-09-09 22:25:46,792:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:46,793:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:46,794:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:46,795:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:46,795:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:46,796:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:46,797:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:46,797:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:46,916:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:46,917:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:46,924:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:46,925:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:46,942:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# Processing atomic distance: 0.6 Angstrom
# 2019-09-09 22:25:46,963:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:46,964:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:46,973:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:46,974:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:46,974:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -0.30000000000000004; H .0 .0 0.30000000000000004
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:46,975:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -1.1011282422677011
# 2019-09-09 22:25:46,975:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.8819620182
# 2019-09-09 22:25:46,976:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -1.983090260467701
# 2019-09-09 22:25:46,976:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:46,977:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:46,978:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:46,978:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:46,979:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -0.30000000000000004
# 2019-09-09 22:25:46,979:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 0.30000000000000004
# 2019-09-09 22:25:46,980:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:46,981:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.64087627  0.83808498]
# 2019-09-09 22:25:46,981:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:46,982:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:46,983:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:46,984:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:46,985:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:46,986:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:46,986:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:46,987:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:47,114:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:47,115:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:47,123:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:47,125:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:47,144:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# 2019-09-09 22:25:47,165:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:47,166:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:47,175:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:47,176:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:47,176:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -0.40000000000000013; H .0 .0 0.40000000000000013
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:47,177:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -1.1108503974765944
# 2019-09-09 22:25:47,178:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.6614715136499999
# 2019-09-09 22:25:47,178:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -1.7723219111265944
# 2019-09-09 22:25:47,180:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:47,181:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:47,181:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:47,182:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:47,183:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -0.4000000000000001
# 2019-09-09 22:25:47,184:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 0.4000000000000001
# 2019-09-09 22:25:47,184:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:47,185:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.55449588  0.61261809]
# 2019-09-09 22:25:47,186:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:47,187:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:47,188:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,189:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,189:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,190:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:47,192:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:47,192:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:47,308:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:47,309:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:47,314:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:47,315:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:47,330:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# Processing atomic distance: 1.0 Angstrom
# 2019-09-09 22:25:47,353:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:47,354:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:47,365:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:47,365:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:47,366:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -0.5000000000000001; H .0 .0 0.5000000000000001
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:47,366:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -1.0661086493179364
# 2019-09-09 22:25:47,367:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.5291772109199999
# 2019-09-09 22:25:47,368:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -1.5952858602379363
# 2019-09-09 22:25:47,369:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:47,369:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:47,370:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:47,371:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:47,371:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -0.5000000000000001
# 2019-09-09 22:25:47,372:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 0.5000000000000001
# 2019-09-09 22:25:47,373:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:47,373:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.48444168  0.45750194]
# 2019-09-09 22:25:47,374:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:47,375:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:47,376:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,377:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,378:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,379:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:47,380:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:47,381:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:47,492:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:47,493:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:47,498:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:47,498:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:47,515:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# 2019-09-09 22:25:47,535:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:47,535:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:47,544:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:47,545:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:47,546:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -0.6000000000000002; H .0 .0 0.6000000000000002
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:47,546:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -1.0051067065684893
# 2019-09-09 22:25:47,547:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.4409810090999999
# 2019-09-09 22:25:47,547:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -1.4460877156684893
# 2019-09-09 22:25:47,548:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:47,549:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:47,550:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:47,550:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:47,551:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -0.6000000000000002
# 2019-09-09 22:25:47,552:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 0.6000000000000002
# 2019-09-09 22:25:47,552:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:47,553:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.42650264  0.34412688]
# 2019-09-09 22:25:47,554:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:47,555:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:47,556:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,557:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,557:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,558:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:47,559:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:47,560:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:47,684:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:47,685:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:47,692:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:47,692:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:47,710:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# Processing atomic distance: 1.4 Angstrom
# 2019-09-09 22:25:47,733:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:47,734:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:47,743:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:47,744:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:47,745:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -0.7000000000000002; H .0 .0 0.7000000000000002
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:47,745:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -0.9414806547077983
# 2019-09-09 22:25:47,746:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.37798372208571424
# 2019-09-09 22:25:47,747:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -1.3194643767935126
# 2019-09-09 22:25:47,747:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:47,748:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:47,749:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:47,749:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:47,750:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -0.7000000000000002
# 2019-09-09 22:25:47,751:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 0.7000000000000002
# 2019-09-09 22:25:47,751:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:47,752:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.37732283  0.25890197]
# 2019-09-09 22:25:47,753:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:47,754:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:47,755:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,755:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,756:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,757:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:47,758:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:47,758:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:47,888:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:47,890:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:47,899:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:47,900:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:47,920:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# 2019-09-09 22:25:47,943:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:47,943:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:47,953:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:47,954:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:47,955:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -0.8000000000000002; H .0 .0 0.8000000000000002
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:47,956:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -0.8817324499460564
# 2019-09-09 22:25:47,956:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.33073575682499995
# 2019-09-09 22:25:47,957:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -1.2124682067710564
# 2019-09-09 22:25:47,957:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:47,958:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:47,958:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:47,959:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:47,961:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -0.8000000000000002
# 2019-09-09 22:25:47,961:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 0.8000000000000002
# 2019-09-09 22:25:47,962:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:47,963:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.33529635  0.19459796]
# 2019-09-09 22:25:47,964:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:47,965:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:47,966:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,967:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,968:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:47,969:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:47,969:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:47,970:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:48,095:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:48,095:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:48,102:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:48,103:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:48,121:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# Processing atomic distance: 1.8 Angstrom
# 2019-09-09 22:25:48,143:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:48,143:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:48,154:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:48,155:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:48,155:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -0.9000000000000002; H .0 .0 0.9000000000000002
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:48,156:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -0.8288481479269767
# 2019-09-09 22:25:48,157:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.29398733939999994
# 2019-09-09 22:25:48,157:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -1.1228354873269766
# 2019-09-09 22:25:48,158:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:48,159:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:48,159:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:48,160:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:48,160:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -0.9000000000000002
# 2019-09-09 22:25:48,161:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 0.9000000000000002
# 2019-09-09 22:25:48,162:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:48,163:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.29956322  0.1459603 ]
# 2019-09-09 22:25:48,164:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:48,165:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:48,166:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,167:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,167:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,168:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:48,169:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:48,170:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:48,294:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:48,295:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:48,302:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:48,303:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:48,320:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# 2019-09-09 22:25:48,342:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:48,343:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:48,352:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:48,353:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:48,353:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -1.0000000000000004; H .0 .0 1.0000000000000004
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:48,354:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -0.7837926542773526
# 2019-09-09 22:25:48,354:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.2645886054599999
# 2019-09-09 22:25:48,355:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -1.0483812597373525
# 2019-09-09 22:25:48,356:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:48,357:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:48,358:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:48,358:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:48,359:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -1.0000000000000004
# 2019-09-09 22:25:48,360:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 1.0000000000000004
# 2019-09-09 22:25:48,360:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:48,361:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.26945922  0.10899737]
# 2019-09-09 22:25:48,362:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:48,362:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:48,364:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,364:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,365:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,366:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:48,367:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:48,368:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:48,477:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:48,478:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:48,484:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:48,484:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:48,500:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# 2019-09-09 22:25:48,520:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:48,521:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# Processing atomic distance: 2.2 Angstrom
# 2019-09-09 22:25:48,530:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:48,531:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:48,531:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -1.1000000000000005; H .0 .0 1.1000000000000005
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:48,532:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -0.7464013499911581
# 2019-09-09 22:25:48,532:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.2405350958727272
# 2019-09-09 22:25:48,533:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -0.9869364458638854
# 2019-09-09 22:25:48,534:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:48,534:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:48,535:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:48,535:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:48,536:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -1.1000000000000003
# 2019-09-09 22:25:48,537:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 1.1000000000000003
# 2019-09-09 22:25:48,537:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:48,538:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.24432699  0.08073271]
# 2019-09-09 22:25:48,539:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:48,540:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:48,541:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,542:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,542:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,543:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:48,543:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:48,544:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:48,665:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:48,666:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:48,673:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:48,673:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:48,694:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# 2019-09-09 22:25:48,716:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:48,717:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:48,727:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:48,728:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:48,728:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -1.2000000000000004; H .0 .0 1.2000000000000004
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:48,729:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -0.7159100604538059
# 2019-09-09 22:25:48,730:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.22049050454999994
# 2019-09-09 22:25:48,730:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -0.9364005650038059
# 2019-09-09 22:25:48,731:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:48,731:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:48,733:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:48,733:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:48,734:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -1.2000000000000004
# 2019-09-09 22:25:48,735:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 1.2000000000000004
# 2019-09-09 22:25:48,736:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:48,738:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.2234857   0.05894803]
# 2019-09-09 22:25:48,738:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:48,739:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:48,740:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,741:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,742:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,743:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:48,743:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:48,744:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:48,863:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:48,863:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:48,869:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:48,870:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:48,887:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# Processing atomic distance: 2.6 Angstrom
# 2019-09-09 22:25:48,908:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:48,908:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:48,918:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:48,919:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:48,920:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -1.3000000000000005; H .0 .0 1.3000000000000005
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:48,921:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -0.6913275611973775
# 2019-09-09 22:25:48,921:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.20352969650769223
# 2019-09-09 22:25:48,922:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -0.8948572577050697
# 2019-09-09 22:25:48,923:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:48,923:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:48,924:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:48,924:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:48,925:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -1.3000000000000005
# 2019-09-09 22:25:48,926:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 1.3000000000000005
# 2019-09-09 22:25:48,927:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:48,927:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.2062814   0.04199598]
# 2019-09-09 22:25:48,928:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:48,929:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:48,930:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,931:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,932:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:48,933:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:48,934:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:48,935:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:49,051:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:49,052:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:49,058:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:49,059:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:49,073:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# 2019-09-09 22:25:49,094:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:49,094:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:49,104:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:49,105:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:49,106:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -1.4000000000000006; H .0 .0 1.4000000000000006
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:49,106:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -0.6716688597517277
# 2019-09-09 22:25:49,107:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.1889918610428571
# 2019-09-09 22:25:49,107:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -0.8606607207945849
# 2019-09-09 22:25:49,108:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:49,109:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:49,109:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:49,110:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:49,110:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -1.4000000000000006
# 2019-09-09 22:25:49,111:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 1.4000000000000006
# 2019-09-09 22:25:49,112:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:49,113:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.19213328  0.02866603]
# 2019-09-09 22:25:49,113:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:49,114:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:49,116:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:49,117:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:49,119:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:49,120:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:49,120:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:49,121:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:49,243:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:49,244:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:49,251:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:49,251:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:49,270:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# Processing atomic distance: 3.0 Angstrom
# 2019-09-09 22:25:49,292:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:49,293:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:49,303:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:49,303:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:49,304:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -1.5000000000000004; H .0 .0 1.5000000000000004
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:49,305:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -0.6560482511455898
# 2019-09-09 22:25:49,305:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.17639240363999995
# 2019-09-09 22:25:49,306:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -0.8324406547855898
# 2019-09-09 22:25:49,307:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:49,307:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:49,308:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:49,308:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:49,309:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -1.5000000000000004
# 2019-09-09 22:25:49,310:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 1.5000000000000004
# 2019-09-09 22:25:49,310:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:49,311:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.18053922  0.01807133]
# 2019-09-09 22:25:49,312:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:49,314:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:49,315:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:49,316:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:49,317:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:49,318:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:49,318:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:49,319:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# 2019-09-09 22:25:49,437:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:49,438:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:49,445:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:49,446:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:49,464:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available
# 2019-09-09 22:25:49,523:qiskit.chemistry.qiskit_chemistry:INFO: Running chemistry problem from input file: None
# 2019-09-09 22:25:49,523:qiskit.chemistry.qiskit_chemistry:INFO: Experiment description: Quantum Chemistry experiment
# 2019-09-09 22:25:49,531:qiskit.chemistry.qmolecule:INFO: Originating driver name: PYSCF
# 2019-09-09 22:25:49,532:qiskit.chemistry.qmolecule:INFO: Originating driver version: ?
# 2019-09-09 22:25:49,533:qiskit.chemistry.qmolecule:INFO: Originating driver config:
# atom=H .0 .0 -0.1; H .0 .0 0.1
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:49,533:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: 0.16417501206169582
# 2019-09-09 22:25:49,534:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 2.6458860546
# 2019-09-09 22:25:49,535:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -2.481711042538304
# 2019-09-09 22:25:49,535:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:49,536:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:49,537:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:49,537:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:49,538:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -0.1
# 2019-09-09 22:25:49,539:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 0.1
# 2019-09-09 22:25:49,539:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:49,540:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.85882453  1.57236203]
# 2019-09-09 22:25:49,541:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:49,541:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# ...
# atom=H .0 .0 -1.1000000000000005; H .0 .0 1.1000000000000005
# unit=Angstrom
# charge=0
# spin=0
# basis=sto3g
# max_memory=Non
# 2019-09-09 22:25:51,490:qiskit.chemistry.qmolecule:INFO: Computed Hartree-Fock energy: -0.7464013499911581
# 2019-09-09 22:25:51,491:qiskit.chemistry.qmolecule:INFO: Nuclear repulsion energy: 0.2405350958727272
# 2019-09-09 22:25:51,492:qiskit.chemistry.qmolecule:INFO: One and two electron Hartree-Fock energy: -0.9869364458638854
# 2019-09-09 22:25:51,492:qiskit.chemistry.qmolecule:INFO: Number of orbitals is 2
# 2019-09-09 22:25:51,493:qiskit.chemistry.qmolecule:INFO: 1 alpha and 1 beta electrons
# 2019-09-09 22:25:51,494:qiskit.chemistry.qmolecule:INFO: Molecule comprises 2 atoms and in xyz format is ::
# 2019-09-09 22:25:51,495:qiskit.chemistry.qmolecule:INFO:   0, 1
# 2019-09-09 22:25:51,495:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, -1.1000000000000003
# 2019-09-09 22:25:51,496:qiskit.chemistry.qmolecule:INFO:   H   0.0, 0.0, 1.1000000000000003
# 2019-09-09 22:25:51,497:qiskit.chemistry.qmolecule:INFO: MO coefficients A: (2, 2)
# 2019-09-09 22:25:51,498:qiskit.chemistry.qmolecule:INFO: Orbital energies A: [-0.24432699  0.08073271]
# 2019-09-09 22:25:51,498:qiskit.chemistry.qmolecule:INFO: One body MO A integrals: (2, 2)
# 2019-09-09 22:25:51,500:qiskit.chemistry.qmolecule:INFO: Two body ERI MO AA integrals: (2, 2, 2, 2)
# 2019-09-09 22:25:51,501:qiskit.chemistry.qmolecule:INFO: x dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:51,502:qiskit.chemistry.qmolecule:INFO: y dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:51,503:qiskit.chemistry.qmolecule:INFO: z dipole MO A integrals: (2, 2)
# 2019-09-09 22:25:51,504:qiskit.chemistry.qmolecule:INFO: Nuclear dipole moment: [0. 0. 0.]
# 2019-09-09 22:25:51,504:qiskit.chemistry.qmolecule:INFO: Reversal of electronic dipole moment sign needed: True
# 2019-09-09 22:25:51,505:qiskit.chemistry.qmolecule:INFO: Core orbitals list []
# Processing atomic distance: 2.2 Angstrom
# 2019-09-09 22:25:51,624:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:51,625:qiskit.aqua.operators.weighted_pauli_operator:INFO: Operator is empty, can not do two qubit reduction. Return the empty operator back.
# 2019-09-09 22:25:51,630:qiskit.chemistry.core.hamiltonian:INFO: Molecule num electrons: [1, 1], remaining for processing: [1, 1]
# 2019-09-09 22:25:51,631:qiskit.chemistry.core.hamiltonian:INFO: Molecule num spin orbitals: 4, remaining for processing: 4
# 2019-09-09 22:25:51,652:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO:
# ==================== Setting of VQE ============================
# Algorithm: VQE
# -- quantum_instance: None
# -- var_form: <qiskit.aqua.components.variational_forms.ry.RY object at 0x13e6c4b38>
# -- optimizer: <qiskit.aqua.components.optimizers.l_bfgs_b.L_BFGS_B object at 0x13e6c4a20>
# -- cost_fn: <bound method VQE._energy_evaluation of <qiskit.aqua.algorithms.adaptive.vqe.vqe.VQE object at 0x13e8529e8>>
# -- initial_point: Random seed
# -- callback: None
# -- operator: Representation: paulis, qubits: 2, size: 5
# -- eval_count: 0
# -- aux_operators: [<qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x136e865f8>, <qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x13efc1fd0>, <qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x13e830240>, <qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x13efbf390>, <qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x13efcd048>, <qiskit.aqua.operators.weighted_pauli_operator.WeightedPauliOperator object at 0x13eaf7c18>]
# -- auto_conversion: True
# ===============================================================
# Variational Form: RY
# -- num_parameters: 4
# -- num_qubits: 2
# -- bounds: [(-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793)]
# -- depth: 1
# -- entanglement: full
# -- entangler_map: [[0, 1]]
# -- entangled_qubits: [0, 1]
# -- initial_state: <qiskit.aqua.components.initial_states.zero.Zero object at 0x13e6c46d8>
# -- entanglement_gate: cz
# -- skip_unentangled_qubits: False
# -- skip_final_ry: False
# ===============================================================
# Optimizer: L_BFGS_B
# -- gradient_support_level: 2
# -- bounds_support_level: 2
# -- initial_point_support_level: 3
# -- options: {'maxfun': 1000, 'maxiter': 10, 'factr': 10, 'iprint': -1, 'epsilon': 1e-08}
# -- max_evals_grouped: 1
# ===============================================================
#
# 2019-09-09 22:25:51,652:qiskit.aqua.quantum_instance:INFO:
# Qiskit Terra version: 0.9.0
# Backend: 'statevector_simulator (AerProvider)', with following setting:
# {'basis_gates': ['u1', 'u2', 'u3', 'cx', 'cz', 'cu1', 'id', 'x', 'y', 'z', 'h', 's', 'sdg', 't', 'tdg', 'ccx', 'swap', 'multiplexer', 'snapshot', 'unitary', 'reset', 'initialize'], 'coupling_map': None}
# {'pass_manager': None, 'initial_layout': None, 'seed_transpiler': None, 'optimization_level': None}
# RunConfig(max_credits=10, shots=1)
# {'timeout': None}
# {}
# {}
# Measurement mitigation: None
# 2019-09-09 22:25:51,653:qiskit.aqua.algorithms.adaptive.vq_algorithm:INFO: Starting optimizer.
# bounds=[(-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793)]
# initial point=[ 1.68954292 -3.04309712 -0.71081292  1.93153971]
# 2019-09-09 22:25:51,670:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 1 returned -0.7826371625858646
# 2019-09-09 22:25:51,687:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 2 returned -0.7826371646922459
# 2019-09-09 22:25:51,704:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 3 returned -0.7826371630973674
# 2019-09-09 22:25:51,720:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 4 returned -0.7826371603637373
# 2019-09-09 22:25:51,737:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 5 returned -0.782637163797108
# 2019-09-09 22:25:51,755:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 6 returned -0.9010040968792528
# 2019-09-09 22:25:51,771:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 7 returned -0.9010040992108104
# 2019-09-09 22:25:51,788:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 8 returned -0.9010040975762805
# 2019-09-09 22:25:51,807:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 9 returned -0.9010040943715213
# 2019-09-09 22:25:51,824:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 10 returned -0.901004097937327
# 2019-09-09 22:25:51,841:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 11 returned -1.0278356766115289
# 2019-09-09 22:25:51,858:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 12 returned -1.0278356786361957
# 2019-09-09 22:25:51,874:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 13 returned -1.0278356774019002
# 2019-09-09 22:25:51,890:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 14 returned -1.0278356743754242
# 2019-09-09 22:25:51,907:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 15 returned -1.0278356772005535
# 2019-09-09 22:25:51,923:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 16 returned -0.8295602431849156
# 2019-09-09 22:25:51,940:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 17 returned -0.8295602409499165
# 2019-09-09 22:25:51,956:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 18 returned -0.829560242812034
# 2019-09-09 22:25:51,972:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 19 returned -0.8295602454085418
# 2019-09-09 22:25:51,989:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 20 returned -0.8295602435577966
# 2019-09-09 22:25:52,006:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 21 returned -1.1729386990366593
# 2019-09-09 22:25:52,022:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 22 returned -1.172938699373307
# 2019-09-09 22:25:52,038:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 23 returned -1.172938698942303
# 2019-09-09 22:25:52,054:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 24 returned -1.1729386985538626
# 2019-09-09 22:25:52,072:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 25 returned -1.1729386993523194
# 2019-09-09 22:25:52,089:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 26 returned -1.177329139042349
# 2019-09-09 22:25:52,106:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 27 returned -1.177329138925453
# 2019-09-09 22:25:52,123:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 28 returned -1.1773291390356846
# 2019-09-09 22:25:52,141:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 29 returned -1.177329139149145
# 2019-09-09 22:25:52,159:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 30 returned -1.1773291390414846
# 2019-09-09 22:25:52,177:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 31 returned -1.177589943500548
# 2019-09-09 22:25:52,194:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 32 returned -1.1775899434768582
# 2019-09-09 22:25:52,211:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 33 returned -1.1775899435225563
# 2019-09-09 22:25:52,227:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 34 returned -1.17758994349609
# 2019-09-09 22:25:52,244:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 35 returned -1.1775899435137562
# 2019-09-09 22:25:52,261:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 36 returned -1.177622110772226
# 2019-09-09 22:25:52,279:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 37 returned -1.1776221107522398
# 2019-09-09 22:25:52,296:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 38 returned -1.177622110789828
# 2019-09-09 22:25:52,312:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 39 returned -1.1776221107616798
# 2019-09-09 22:25:52,328:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 40 returned -1.1776221107923888
# 2019-09-09 22:25:52,344:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 41 returned -1.1777309124581188
# 2019-09-09 22:25:52,360:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 42 returned -1.1777309124517437
# 2019-09-09 22:25:52,376:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 43 returned -1.177730912458822
# 2019-09-09 22:25:52,392:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 44 returned -1.1777309124240625
# 2019-09-09 22:25:52,409:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 45 returned -1.1777309125055666
# 2019-09-09 22:25:52,426:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 46 returned -1.1787373898489704
# 2019-09-09 22:25:52,442:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 47 returned -1.1787373898391986
# 2019-09-09 22:25:52,458:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 48 returned -1.1787373898169449
# 2019-09-09 22:25:52,475:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 49 returned -1.1787373897881304
# 2019-09-09 22:25:52,491:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 50 returned -1.1787373899492206
# 2019-09-09 22:25:52,507:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 51 returned -1.1620691279298
# 2019-09-09 22:25:52,524:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 52 returned -1.1620691276539408
# 2019-09-09 22:25:52,541:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 53 returned -1.1620691275701136
# 2019-09-09 22:25:52,558:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 54 returned -1.1620691288809195
# 2019-09-09 22:25:52,574:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 55 returned -1.1620691269820411
# 2019-09-09 22:25:52,591:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 56 returned -1.1798574413703844
# 2019-09-09 22:25:52,607:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 57 returned -1.1798574412970528
# 2019-09-09 22:25:52,623:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 58 returned -1.179857441322267
# 2019-09-09 22:25:52,639:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 59 returned -1.1798574413965497
# 2019-09-09 22:25:52,655:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 60 returned -1.1798574414165484
# 2019-09-09 22:25:52,672:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 61 returned -1.1800906235330682
# 2019-09-09 22:25:52,688:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 62 returned -1.1800906234058977
# 2019-09-09 22:25:52,704:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 63 returned -1.180090623465876
# 2019-09-09 22:25:52,721:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 64 returned -1.1800906236745572
# 2019-09-09 22:25:52,737:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 65 returned -1.1800906234785329
# 2019-09-09 22:25:52,754:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 66 returned -1.180408850338515
# 2019-09-09 22:25:52,770:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 67 returned -1.1804088502891212
# 2019-09-09 22:25:52,787:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 68 returned -1.1804088503446972
# 2019-09-09 22:25:52,803:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 69 returned -1.1804088503744359
# 2019-09-09 22:25:52,820:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 70 returned -1.1804088503283783
# 2019-09-09 22:25:52,837:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 71 returned -1.1797718968028983
# 2019-09-09 22:25:52,855:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 72 returned -1.179771896774957
# 2019-09-09 22:25:52,871:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 73 returned -1.179771896892806
# 2019-09-09 22:25:52,888:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 74 returned -1.1797718970897058
# 2019-09-09 22:25:52,904:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 75 returned -1.1797718964989368
# 2019-09-09 22:25:52,921:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 76 returned -1.1807771110288843
# 2019-09-09 22:25:52,938:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 77 returned -1.1807771109971752
# 2019-09-09 22:25:52,955:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 78 returned -1.1807771110900513
# 2019-09-09 22:25:52,972:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 79 returned -1.1807771111228114
# 2019-09-09 22:25:52,990:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 80 returned -1.180777110925797
# 2019-09-09 22:25:53,007:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 81 returned -1.181051970868007
# 2019-09-09 22:25:53,023:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 82 returned -1.1810519708439509
# 2019-09-09 22:25:53,039:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 83 returned -1.1810519709219705
# 2019-09-09 22:25:53,055:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 84 returned -1.181051970956426
# 2019-09-09 22:25:53,072:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Energy evaluation 85 returned -1.1810519707722689
# 2019-09-09 22:25:53,073:qiskit.aqua.algorithms.adaptive.vqe.vqe:INFO: Optimization complete in 1.419814109802246 seconds.
# Found opt_params [ 1.74921801 -2.0682302  -2.12727842  2.57550707] in 85 evals
# 2019-09-09 22:25:53,129:qiskit.chemistry.qiskit_chemistry:INFO: Processing complete. Final result available

# %% [markdown]
# Now we plot the results of the dissociation profile for the executed algorithms

# %%
for i, algo in enumerate(algos):
    if algo == 'VQE':
        plt.plot(mol_distances_vqe, energy_vqe[i], label=algo, linestyle='', marker='x')
    else:
        plt.plot(mol_distances, energy[i], label=algo)
        
plt.xlabel('Atomic distance (Angstrom)')
plt.ylabel('Energy [Ha]')
plt.legend()
plt.show()

# %% [markdown]
# We want now to visualise the error we are making with the exact solution.

# %%
mol_distances_errors = []
energy_errors = []

for i, pts_vqe in enumerate(mol_distances_vqe):
    for j, pts in enumerate(mol_distances):
        # find the entries with same bond distances
        if pts_vqe == pts:
            mol_distances_errors.append(pts)
            energy_errors.append(abs(energy[0][j]-energy_vqe[1][i]))
            
# plot the errors
print('Errors |Exact - VQE|:\n',energy_errors)
plt.plot(mol_distances_errors, energy_errors, label='Errors(Exact-VQE)', linestyle='', marker='x')

# chemical accuracy of 1 mHa
plt.hlines(0.001, 0, 3, colors='k', label='Chemical Accuracy')
plt.legend()
plt.show()
# Out:
# Errors |Exact - VQE|:
#  [0.006692877264558028, 1.3886669592011458e-12, 0.0007071586979825462]

# %% [markdown]
# # Exercises

# %% [markdown]
# - Set the VQE for H2 using UCCSD, RYRZ, SWAPRZ in STO-3G and compare the results for a given geometry using state_vector simulator with L_BFGS_B optimizer. What is the error with respect to UCCSD ?
# - Change depth parameter (repetition of circuit with independent parameters) of RYRZ, SWAPRZ circuit to reach chemical accuracy.
# - Change just the basis set from STO-3G to 6-31G and play with active_occupied/unoccupied orbital parameters (change of active space) in UCCSD Variational Form. This is basically the work we performed in [2] so you will be performing ! :-)
#
# [2] Panagiotis Kl. Barkoutsos, Jerome F. Gonthier, Igor Sokolov, Nikolaj Moll, Gian Salis, Andreas Fuhrer, Marc Ganzhorn, Daniel J. Egger, Matthias Troyer, Antonio Mezzacapo, Stefan Filipp, and Ivano Tavernelli *Quantum algorithms for electronic structure calculations: Particle-hole Hamiltonian and optimized wave-function expansions* Phys. Rev. A 98, 022322 – Published 20 August 2018

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# %qiskit_copyright
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td>Qiskit</td><td>0.12.0</td></tr><tr><td>Terra</td><td>0.9.0</td></tr><tr><td>Aer</td><td>0.3.0</td></tr><tr><td>Ignis</td><td>0.2.0</td></tr><tr><td>Aqua</td><td>0.6.0</td></tr><tr><td>IBM Q Provider</td><td>0.3.2</td></tr><tr><th>System information</th></tr><tr><td>Python</td><td>3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 14:38:56)
# [Clang 4.0.1 (tags/RELEASE_401/final)]</td></tr><tr><td>OS</td><td>Darwin</td></tr><tr><td>CPUs</td><td>6</td></tr><tr><td>Memory (Gb)</td><td>16.0</td></tr><tr><td colspan='2'>Mon Sep 09 22:48:45 2019 CEST</td></tr></table>
# <div style='width: 100%; background-color:#d5d9e0;padding-left: 10px; padding-bottom: 10px; padding-right: 10px; padding-top: 5px'><h3>This code is a part of Qiskit</h3><p>&copy; Copyright IBM 2017, 2019.</p><p>This code is licensed under the Apache License, Version 2.0. You may<br>obtain a copy of this license in the LICENSE.txt file in the root directory<br> of this source tree or at http://www.apache.org/licenses/LICENSE-2.0.<p>Any modifications or derivative works of this code must retain this<br>copyright notice, and modified files need to carry a notice indicating<br>that they have been altered from the originals.</p></div>
